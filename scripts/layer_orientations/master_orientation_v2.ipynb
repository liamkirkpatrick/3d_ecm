# %% [markdown]
# # Master Orientation V2
#
# Major improvement over v1 is to do the depth adjustment between the two pairs of tracks, rather than the whole chunk

# %% [markdown]
# ## Import packages

# %%
# general
import numpy as np
import pandas as pd
import math
from scipy import stats

# progress bar
from tqdm import tqdm

# plotting
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# my functions/classes
import sys
sys.path.append("../core_scripts/")
from ECMclass import ECM
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## User Inputs

# %%
# paths
path_to_data = '../../data/'
path_to_angles = '../../data/angles/'
metadata_file = 'metadata.csv'
path_to_angles = '../../data/angles'

# smoothing window
window = 10

meta = pd.read_csv(path_to_data+metadata_file)

# %% [markdown]
# ## Minor Functions

# %%
# define function to find unique elements in list
def unique(list1):
 
    # initialize a null list
    unique_list = []
 
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    
    return(unique_list)

# %% [markdown]
# ## Major Functions

# %%
def compute_dip(data):

    column_names = ['section']
    unique_sec = unique(sections)
    df = pd.DataFrame(unique_sec,columns=column_names)
    df['depth'] = 0

    # set up the angle range
    angle_res = 0.1
    angle_low = -75
    angle_high = 75
    test_angle = np.linspace(angle_low,angle_high,int((angle_high-angle_low)/angle_res+1))

    # loop through each file
    for d in data:

        # Print the current file being processed
        print("Calculating File - "+d.core+
              " - "+d.section+
              " - "+d.face+
              " - "+d.ACorDC)
        
        # assign local variables
        depth = d.depth_s
        meas = d.meas_s
        button = d.button_s
        y_list = d.y_s
        y_vec = d.y_vec

        # set empty lists for angles, scores, and lengths
        angles = []
        scores = []
        lengths = []

        # loop through each pair of tracks
        for i in range(len(y_vec)-1):
            for j in range(i+1,len(y_vec)):
                
                # get the y values for the two tracks
                y1 = y_vec[i]
                y2 = y_vec[j]
                ymid = (y1+y2)/2
                y_space = abs(y1-y2)/2/1000

                # Print the current pair of tracks being processed
                print("    Calculating Pair - "+str(i)+" - "+str(j)+" - y1: "+str(y1)+" - y2: "+str(y2))

                # check y1 and y2 are seprated by more than 5mm
                if abs(y1-y2) > 5:

                    # get the depth, meas, and button values for the two tracks
                    depth1 = depth[y_list==y1]
                    depth2 = depth[y_list==y2]
                    meas1 = meas[y_list==y1]
                    meas2 = meas[y_list==y2]
                    button1 = button[y_list==y1]
                    button2 = button[y_list==y2]
                    
                    # get a common depth
                    common_depths = np.arange(np.round(min(depth1.min(),depth2.min()),3),np.round(max(depth1.max(),depth2.max()),3),0.001)

                    # interpolate button and meas values to common depths
                    button1 = np.interp(common_depths, depth1, button1)
                    button2 = np.interp(common_depths, depth2, button2)

                    # find the longest stretch of common depths where button is 0 for both tracks
                    button_com = np.logical_and(button1==0,button2==0)
                    common_depths = common_depths[button_com]

                    # check that button_com is not empty
                    if common_depths.size != 0:
                    
                        # get dmin and dmax
                        dmin = common_depths.min() + np.tan(np.deg2rad(angle_high)) * y_space + 0.001
                        dmax = common_depths.max() - np.tan(np.deg2rad(angle_high)) * y_space - 0.001

                        # if overall length is >40 
                        if dmax - dmin > 0.4:

                            # compute a vector at 1mm spacing between dmin and dmax. Round up from dmin and down from dmax
                            dmin = np.ceil(dmin * 1000) / 1000
                            dmax = np.floor(dmax * 1000) / 1000
                            cds = np.arange(dmin, dmax, 0.001)

                            # save length
                            lengths.append(np.round(dmax - dmin,3))

                            # # update meas1 and meas2 to be at common depths
                            # meas1 = np.interp(cds, common_depths, meas1)
                            # meas2 = np.interp(cds, common_depths, meas2)

                            # print updated dmin and dmax
                            #print("        dmin: "+str(dmin)+" - dmax: "+str(dmax))

                            # now, loop through each angle
                            max_rho = 0
                            best_angle = 0
                            for angle in test_angle:

                                # get the offset for the angle
                                offset = np.tan(np.deg2rad(angle)) * y_space
                                depth1_angle = depth1 + offset
                                depth2_angle = depth2 - offset

                                # # get the meas values for the two tracks where depth1 and depth2 are within dmin and dmax
                                # meas1_angle = meas1[(depth1_angle >= dmin) & (depth1_angle <= dmax)]
                                # meas2_angle = meas2[(depth2_angle >= dmin) & (depth2_angle <= dmax)]

                                # interpolate the meas values to the common depths
                                meas1_angle= np.interp(cds, np.flip(depth1_angle), np.flip(meas1))
                                meas2_angle = np.interp(cds, np.flip(depth2_angle), np.flip(meas2))

                                # compute the correlation between the two tracks
                                rho, pval = stats.pearsonr(meas1_angle, meas2_angle)
                                if rho>max_rho:
                                    max_rho = np.round(rho,5)
                                    best_angle = np.round(angle,5)
                    
                            scores.append(max_rho)
                            angles.append(best_angle)

                        else:
                            print("        Not enough common depths for pair")

                else:
                    print("        Not enough separation between tracks for pair")
                    continue

                # Print the best angle and max rho
                #print("        Best angle: "+str(best_angle)+" - Max rho: "+str(max_rho))


        # add data to dataframe
        sec_idx = unique_sec.index(d.section)
        df.loc[sec_idx,'section'] = d.section
        df.loc[sec_idx,'depth'] = np.mean(d.depth)
        angle_rowname = d.ACorDC + '-'+d.face + '-angles'
        score_rowname = d.ACorDC + '-'+d.face + '-scores'
        length_rowname = d.ACorDC + '-'+d.face + '-length'
        if angle_rowname not in df.columns:
            df[angle_rowname] = None
            df[score_rowname] = None
            df[length_rowname] = None
        df.at[sec_idx, angle_rowname] = angles
        df.at[sec_idx, score_rowname] = scores
        df.at[sec_idx, length_rowname] = lengths


    return df

# %% [markdown]
# ## Compute ALHIC2302 orientation calculations

# %%
# import each script as an ECM class item
data = []
cores = []
sections = []
faces = []
ACorDCs = []
max_tracks = 0
for index,row in meta.iterrows():
    
    core = row['core']
    section = row['section']
    section_num = section.split("_")
    face = row['face']
    ACorDC = row['ACorDC']
    
    if core == 'alhic2302' and ACorDC == 'AC':
        
        print("Reading "+core+", section "+section+'-'+face+'-'+ACorDC)
    
        data_item = ECM(core,section,face,ACorDC)
        data_item.rem_ends(10)
        data_item.smooth(window)
        data.append(data_item)
        
        cores.append(core)
        sections.append(section)
        faces.append(face)
        ACorDCs.append(ACorDC)
        
        if len(data_item.y_vec)>max_tracks:
            max_tracks = len(data_item.y_vec)
# Out:
# Reading alhic2302, section 10-l-AC
# Reading alhic2302, section 10-t-AC
# Reading alhic2302, section 12-l-AC
# Reading alhic2302, section 12-t-AC
# Reading alhic2302, section 13-l-AC
# Reading alhic2302, section 13-t-AC
# Reading alhic2302, section 14-l-AC
# Reading alhic2302, section 14-t-AC
# Reading alhic2302, section 15-l-AC
# Reading alhic2302, section 15-t-AC
# Reading alhic2302, section 16-l-AC
# Reading alhic2302, section 16-t-AC
# Reading alhic2302, section 17-l-AC
# Reading alhic2302, section 17-t-AC
# Reading alhic2302, section 18-l-AC
# Reading alhic2302, section 18-t-AC
# Reading alhic2302, section 19-l-AC
# Reading alhic2302, section 19-t-AC
# Reading alhic2302, section 20-l-AC
# Reading alhic2302, section 20-t-AC
# Reading alhic2302, section 21-l-AC
# Reading alhic2302, section 21-t-AC
# Reading alhic2302, section 22-l-AC
# Reading alhic2302, section 22-t-AC
# Reading alhic2302, section 22-t-AC
# Reading alhic2302, section 23-l-AC
# Reading alhic2302, section 23-t-AC
# Reading alhic2302, section 24-l-AC
# Reading alhic2302, section 24-t-AC
# Reading alhic2302, section 25-l-AC
# Reading alhic2302, section 25-t-AC
# Reading alhic2302, section 26-l-AC
# Reading alhic2302, section 26-t-AC
# Reading alhic2302, section 27-l-AC
# Reading alhic2302, section 27-t-AC
# Reading alhic2302, section 28-l-AC
# Reading alhic2302, section 28-t-AC
# Reading alhic2302, section 29-l-AC
# Reading alhic2302, section 29-t-AC
# Reading alhic2302, section 30-l-AC
# Reading alhic2302, section 30-t-AC
# Reading alhic2302, section 31-l-AC
# Reading alhic2302, section 31-t-AC
# Reading alhic2302, section 32-l-AC
# Reading alhic2302, section 32-t-AC
# Reading alhic2302, section 33-l-AC
# Reading alhic2302, section 33-t-AC
# Reading alhic2302, section 34-l-AC
# Reading alhic2302, section 34-t-AC
# Reading alhic2302, section 35-l-AC
# Reading alhic2302, section 35-t-AC
# Reading alhic2302, section 36-l-AC
# Reading alhic2302, section 36-t-AC
# Reading alhic2302, section 37-l-AC
# Reading alhic2302, section 37-t-AC
# Reading alhic2302, section 38-l-AC
# Reading alhic2302, section 38-t-AC
# Reading alhic2302, section 39-l-AC
# Reading alhic2302, section 39-t-AC
# Reading alhic2302, section 40-l-AC
# Reading alhic2302, section 40-t-AC
# Reading alhic2302, section 41-l-AC
# Reading alhic2302, section 41-t-AC
# Reading alhic2302, section 42-l-AC
# Reading alhic2302, section 42-t-AC
# Reading alhic2302, section 46-l-AC
# Reading alhic2302, section 46-t-AC
# Reading alhic2302, section 47-l-AC
# Reading alhic2302, section 47-t-AC
# Reading alhic2302, section 48-l-AC
# Reading alhic2302, section 48-t-AC
# Reading alhic2302, section 49-l-AC
# Reading alhic2302, section 49-t-AC
# Reading alhic2302, section 50-l-AC
# Reading alhic2302, section 50-t-AC
# Reading alhic2302, section 51_2-l-AC
# Reading alhic2302, section 51_2-t-AC
# Reading alhic2302, section 52_1-l-AC
# Reading alhic2302, section 52_1-t-AC

# %%
alhic2302 = compute_dip(data)

# save the dataframe to a csv file
alhic2302.to_pickle('../../data/angles/alhic2302_angles_v2.df')
# Out:
# Calculating File - alhic2302 - 10 - l - AC
#     Calculating Pair - 0 - 1 - y1: 61.231 - y2: 81.231
#     Calculating Pair - 0 - 2 - y1: 61.231 - y2: 101.231
#     Calculating Pair - 0 - 3 - y1: 61.231 - y2: 121.231
#     Calculating Pair - 0 - 4 - y1: 61.231 - y2: 141.231
#     Calculating Pair - 0 - 5 - y1: 61.231 - y2: 151.478
#     Calculating Pair - 1 - 2 - y1: 81.231 - y2: 101.231
#     Calculating Pair - 1 - 3 - y1: 81.231 - y2: 121.231
#     Calculating Pair - 1 - 4 - y1: 81.231 - y2: 141.231
#     Calculating Pair - 1 - 5 - y1: 81.231 - y2: 151.478
#     Calculating Pair - 2 - 3 - y1: 101.231 - y2: 121.231
#     Calculating Pair - 2 - 4 - y1: 101.231 - y2: 141.231
#     Calculating Pair - 2 - 5 - y1: 101.231 - y2: 151.478
#     Calculating Pair - 3 - 4 - y1: 121.231 - y2: 141.231
#     Calculating Pair - 3 - 5 - y1: 121.231 - y2: 151.478
#     Calculating Pair - 4 - 5 - y1: 141.231 - y2: 151.478
# Calculating File - alhic2302 - 10 - t - AC
#     Calculating Pair - 0 - 1 - y1: 72.482 - y2: 92.482
#     Calculating Pair - 0 - 2 - y1: 72.482 - y2: 112.482
#     Calculating Pair - 0 - 3 - y1: 72.482 - y2: 132.482
#     Calculating Pair - 0 - 4 - y1: 72.482 - y2: 152.482
#     Calculating Pair - 0 - 5 - y1: 72.482 - y2: 164.137
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 92.482 - y2: 112.482
#     Calculating Pair - 1 - 3 - y1: 92.482 - y2: 132.482
#     Calculating Pair - 1 - 4 - y1: 92.482 - y2: 152.482
#     Calculating Pair - 1 - 5 - y1: 92.482 - y2: 164.137
#     Calculating Pair - 2 - 3 - y1: 112.482 - y2: 132.482
#     Calculating Pair - 2 - 4 - y1: 112.482 - y2: 152.482
#     Calculating Pair - 2 - 5 - y1: 112.482 - y2: 164.137
#     Calculating Pair - 3 - 4 - y1: 132.482 - y2: 152.482
#     Calculating Pair - 3 - 5 - y1: 132.482 - y2: 164.137
#     Calculating Pair - 4 - 5 - y1: 152.482 - y2: 164.137
# Calculating File - alhic2302 - 12 - l - AC
#     Calculating Pair - 0 - 1 - y1: 59.579 - y2: 79.579
#     Calculating Pair - 0 - 2 - y1: 59.579 - y2: 99.579
#     Calculating Pair - 0 - 3 - y1: 59.579 - y2: 119.579
#     Calculating Pair - 0 - 4 - y1: 59.579 - y2: 139.579
#     Calculating Pair - 0 - 5 - y1: 59.579 - y2: 150.125
#     Calculating Pair - 1 - 2 - y1: 79.579 - y2: 99.579
#     Calculating Pair - 1 - 3 - y1: 79.579 - y2: 119.579
#     Calculating Pair - 1 - 4 - y1: 79.579 - y2: 139.579
#     Calculating Pair - 1 - 5 - y1: 79.579 - y2: 150.125
#     Calculating Pair - 2 - 3 - y1: 99.579 - y2: 119.579
#     Calculating Pair - 2 - 4 - y1: 99.579 - y2: 139.579
#     Calculating Pair - 2 - 5 - y1: 99.579 - y2: 150.125
#     Calculating Pair - 3 - 4 - y1: 119.579 - y2: 139.579
#     Calculating Pair - 3 - 5 - y1: 119.579 - y2: 150.125
#     Calculating Pair - 4 - 5 - y1: 139.579 - y2: 150.125
# Calculating File - alhic2302 - 12 - t - AC
#     Calculating Pair - 0 - 1 - y1: 76.264 - y2: 96.264
#     Calculating Pair - 0 - 2 - y1: 76.264 - y2: 116.264
#     Calculating Pair - 0 - 3 - y1: 76.264 - y2: 136.264
#     Calculating Pair - 0 - 4 - y1: 76.264 - y2: 156.264
#     Calculating Pair - 0 - 5 - y1: 76.264 - y2: 161.198
#     Calculating Pair - 1 - 2 - y1: 96.264 - y2: 116.264
#     Calculating Pair - 1 - 3 - y1: 96.264 - y2: 136.264
#     Calculating Pair - 1 - 4 - y1: 96.264 - y2: 156.264
#     Calculating Pair - 1 - 5 - y1: 96.264 - y2: 161.198
#     Calculating Pair - 2 - 3 - y1: 116.264 - y2: 136.264
#     Calculating Pair - 2 - 4 - y1: 116.264 - y2: 156.264
#     Calculating Pair - 2 - 5 - y1: 116.264 - y2: 161.198
#     Calculating Pair - 3 - 4 - y1: 136.264 - y2: 156.264
#     Calculating Pair - 3 - 5 - y1: 136.264 - y2: 161.198
#     Calculating Pair - 4 - 5 - y1: 156.264 - y2: 161.198
#         Not enough separation between tracks for pair
# Calculating File - alhic2302 - 13 - l - AC
#     Calculating Pair - 0 - 1 - y1: 55.493 - y2: 75.493
#     Calculating Pair - 0 - 2 - y1: 55.493 - y2: 95.493
#     Calculating Pair - 0 - 3 - y1: 55.493 - y2: 115.493
#     Calculating Pair - 0 - 4 - y1: 55.493 - y2: 135.493
#     Calculating Pair - 0 - 5 - y1: 55.493 - y2: 149.606
#     Calculating Pair - 1 - 2 - y1: 75.493 - y2: 95.493
#     Calculating Pair - 1 - 3 - y1: 75.493 - y2: 115.493
#     Calculating Pair - 1 - 4 - y1: 75.493 - y2: 135.493
#     Calculating Pair - 1 - 5 - y1: 75.493 - y2: 149.606
#     Calculating Pair - 2 - 3 - y1: 95.493 - y2: 115.493
#     Calculating Pair - 2 - 4 - y1: 95.493 - y2: 135.493
#     Calculating Pair - 2 - 5 - y1: 95.493 - y2: 149.606
#     Calculating Pair - 3 - 4 - y1: 115.493 - y2: 135.493
#     Calculating Pair - 3 - 5 - y1: 115.493 - y2: 149.606
#     Calculating Pair - 4 - 5 - y1: 135.493 - y2: 149.606
# Calculating File - alhic2302 - 13 - t - AC
#     Calculating Pair - 0 - 1 - y1: 58.234 - y2: 78.234
#     Calculating Pair - 0 - 2 - y1: 58.234 - y2: 98.234
#     Calculating Pair - 0 - 3 - y1: 58.234 - y2: 118.234
#     Calculating Pair - 0 - 4 - y1: 58.234 - y2: 138.234
#     Calculating Pair - 0 - 5 - y1: 58.234 - y2: 140.111
#     Calculating Pair - 1 - 2 - y1: 78.234 - y2: 98.234
#     Calculating Pair - 1 - 3 - y1: 78.234 - y2: 118.234
#     Calculating Pair - 1 - 4 - y1: 78.234 - y2: 138.234
#     Calculating Pair - 1 - 5 - y1: 78.234 - y2: 140.111
#     Calculating Pair - 2 - 3 - y1: 98.234 - y2: 118.234
#     Calculating Pair - 2 - 4 - y1: 98.234 - y2: 138.234
#     Calculating Pair - 2 - 5 - y1: 98.234 - y2: 140.111
#     Calculating Pair - 3 - 4 - y1: 118.234 - y2: 138.234
#     Calculating Pair - 3 - 5 - y1: 118.234 - y2: 140.111
#     Calculating Pair - 4 - 5 - y1: 138.234 - y2: 140.111
#         Not enough separation between tracks for pair
# Calculating File - alhic2302 - 14 - l - AC
#     Calculating Pair - 0 - 1 - y1: 64.623 - y2: 84.623
#     Calculating Pair - 0 - 2 - y1: 64.623 - y2: 104.623
#     Calculating Pair - 0 - 3 - y1: 64.623 - y2: 124.623
#     Calculating Pair - 0 - 4 - y1: 64.623 - y2: 144.623
#     Calculating Pair - 0 - 5 - y1: 64.623 - y2: 151.71
#     Calculating Pair - 1 - 2 - y1: 84.623 - y2: 104.623
#     Calculating Pair - 1 - 3 - y1: 84.623 - y2: 124.623
#     Calculating Pair - 1 - 4 - y1: 84.623 - y2: 144.623
#     Calculating Pair - 1 - 5 - y1: 84.623 - y2: 151.71
#     Calculating Pair - 2 - 3 - y1: 104.623 - y2: 124.623
#     Calculating Pair - 2 - 4 - y1: 104.623 - y2: 144.623
#     Calculating Pair - 2 - 5 - y1: 104.623 - y2: 151.71
#     Calculating Pair - 3 - 4 - y1: 124.623 - y2: 144.623
#     Calculating Pair - 3 - 5 - y1: 124.623 - y2: 151.71
#     Calculating Pair - 4 - 5 - y1: 144.623 - y2: 151.71
# Calculating File - alhic2302 - 14 - t - AC
#     Calculating Pair - 0 - 1 - y1: 59.291 - y2: 79.291
#     Calculating Pair - 0 - 2 - y1: 59.291 - y2: 99.291
#     Calculating Pair - 0 - 3 - y1: 59.291 - y2: 119.291
#     Calculating Pair - 0 - 4 - y1: 59.291 - y2: 139.291
#     Calculating Pair - 0 - 5 - y1: 59.291 - y2: 152.33
#     Calculating Pair - 1 - 2 - y1: 79.291 - y2: 99.291
#     Calculating Pair - 1 - 3 - y1: 79.291 - y2: 119.291
#     Calculating Pair - 1 - 4 - y1: 79.291 - y2: 139.291
#     Calculating Pair - 1 - 5 - y1: 79.291 - y2: 152.33
#     Calculating Pair - 2 - 3 - y1: 99.291 - y2: 119.291
#     Calculating Pair - 2 - 4 - y1: 99.291 - y2: 139.291
#     Calculating Pair - 2 - 5 - y1: 99.291 - y2: 152.33
#     Calculating Pair - 3 - 4 - y1: 119.291 - y2: 139.291
#     Calculating Pair - 3 - 5 - y1: 119.291 - y2: 152.33
#     Calculating Pair - 4 - 5 - y1: 139.291 - y2: 152.33
# Calculating File - alhic2302 - 15 - l - AC
#     Calculating Pair - 0 - 1 - y1: 57.768 - y2: 77.768
#     Calculating Pair - 0 - 2 - y1: 57.768 - y2: 97.768
#     Calculating Pair - 0 - 3 - y1: 57.768 - y2: 117.768
#     Calculating Pair - 0 - 4 - y1: 57.768 - y2: 137.768
#     Calculating Pair - 0 - 5 - y1: 57.768 - y2: 152.312
#     Calculating Pair - 1 - 2 - y1: 77.768 - y2: 97.768
#     Calculating Pair - 1 - 3 - y1: 77.768 - y2: 117.768
#     Calculating Pair - 1 - 4 - y1: 77.768 - y2: 137.768
#     Calculating Pair - 1 - 5 - y1: 77.768 - y2: 152.312
#     Calculating Pair - 2 - 3 - y1: 97.768 - y2: 117.768
#     Calculating Pair - 2 - 4 - y1: 97.768 - y2: 137.768
#     Calculating Pair - 2 - 5 - y1: 97.768 - y2: 152.312
#     Calculating Pair - 3 - 4 - y1: 117.768 - y2: 137.768
#     Calculating Pair - 3 - 5 - y1: 117.768 - y2: 152.312
#     Calculating Pair - 4 - 5 - y1: 137.768 - y2: 152.312
# Calculating File - alhic2302 - 15 - t - AC
#     Calculating Pair - 0 - 1 - y1: 61.653 - y2: 81.653
#     Calculating Pair - 0 - 2 - y1: 61.653 - y2: 101.653
#     Calculating Pair - 0 - 3 - y1: 61.653 - y2: 121.653
#     Calculating Pair - 0 - 4 - y1: 61.653 - y2: 141.653
#     Calculating Pair - 0 - 5 - y1: 61.653 - y2: 155.588
#     Calculating Pair - 1 - 2 - y1: 81.653 - y2: 101.653
#     Calculating Pair - 1 - 3 - y1: 81.653 - y2: 121.653
#     Calculating Pair - 1 - 4 - y1: 81.653 - y2: 141.653
#     Calculating Pair - 1 - 5 - y1: 81.653 - y2: 155.588
#     Calculating Pair - 2 - 3 - y1: 101.653 - y2: 121.653
#     Calculating Pair - 2 - 4 - y1: 101.653 - y2: 141.653
#     Calculating Pair - 2 - 5 - y1: 101.653 - y2: 155.588
#     Calculating Pair - 3 - 4 - y1: 121.653 - y2: 141.653
#     Calculating Pair - 3 - 5 - y1: 121.653 - y2: 155.588
#     Calculating Pair - 4 - 5 - y1: 141.653 - y2: 155.588
# Calculating File - alhic2302 - 16 - l - AC
#     Calculating Pair - 0 - 1 - y1: 65.283 - y2: 85.283
#     Calculating Pair - 0 - 2 - y1: 65.283 - y2: 105.283
#     Calculating Pair - 0 - 3 - y1: 65.283 - y2: 125.283
#     Calculating Pair - 0 - 4 - y1: 65.283 - y2: 145.283
#     Calculating Pair - 0 - 5 - y1: 65.283 - y2: 152.982
#     Calculating Pair - 1 - 2 - y1: 85.283 - y2: 105.283
#     Calculating Pair - 1 - 3 - y1: 85.283 - y2: 125.283
#     Calculating Pair - 1 - 4 - y1: 85.283 - y2: 145.283
#     Calculating Pair - 1 - 5 - y1: 85.283 - y2: 152.982
#     Calculating Pair - 2 - 3 - y1: 105.283 - y2: 125.283
#     Calculating Pair - 2 - 4 - y1: 105.283 - y2: 145.283
#     Calculating Pair - 2 - 5 - y1: 105.283 - y2: 152.982
#     Calculating Pair - 3 - 4 - y1: 125.283 - y2: 145.283
#     Calculating Pair - 3 - 5 - y1: 125.283 - y2: 152.982
#     Calculating Pair - 4 - 5 - y1: 145.283 - y2: 152.982
# Calculating File - alhic2302 - 16 - t - AC
#     Calculating Pair - 0 - 1 - y1: 61.66 - y2: 81.66
#     Calculating Pair - 0 - 2 - y1: 61.66 - y2: 101.66
#     Calculating Pair - 0 - 3 - y1: 61.66 - y2: 121.66
#     Calculating Pair - 0 - 4 - y1: 61.66 - y2: 141.66
#     Calculating Pair - 0 - 5 - y1: 61.66 - y2: 157.78
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 81.66 - y2: 101.66
#     Calculating Pair - 1 - 3 - y1: 81.66 - y2: 121.66
#     Calculating Pair - 1 - 4 - y1: 81.66 - y2: 141.66
#     Calculating Pair - 1 - 5 - y1: 81.66 - y2: 157.78
#     Calculating Pair - 2 - 3 - y1: 101.66 - y2: 121.66
#     Calculating Pair - 2 - 4 - y1: 101.66 - y2: 141.66
#     Calculating Pair - 2 - 5 - y1: 101.66 - y2: 157.78
#     Calculating Pair - 3 - 4 - y1: 121.66 - y2: 141.66
#     Calculating Pair - 3 - 5 - y1: 121.66 - y2: 157.78
#     Calculating Pair - 4 - 5 - y1: 141.66 - y2: 157.78
# Calculating File - alhic2302 - 17 - l - AC
#     Calculating Pair - 0 - 1 - y1: 48.131 - y2: 68.131
#     Calculating Pair - 0 - 2 - y1: 48.131 - y2: 88.131
#     Calculating Pair - 0 - 3 - y1: 48.131 - y2: 108.131
#     Calculating Pair - 0 - 4 - y1: 48.131 - y2: 128.131
#     Calculating Pair - 0 - 5 - y1: 48.131 - y2: 138.971
#     Calculating Pair - 1 - 2 - y1: 68.131 - y2: 88.131
#     Calculating Pair - 1 - 3 - y1: 68.131 - y2: 108.131
#     Calculating Pair - 1 - 4 - y1: 68.131 - y2: 128.131
#     Calculating Pair - 1 - 5 - y1: 68.131 - y2: 138.971
#     Calculating Pair - 2 - 3 - y1: 88.131 - y2: 108.131
#     Calculating Pair - 2 - 4 - y1: 88.131 - y2: 128.131
#     Calculating Pair - 2 - 5 - y1: 88.131 - y2: 138.971
#     Calculating Pair - 3 - 4 - y1: 108.131 - y2: 128.131
#     Calculating Pair - 3 - 5 - y1: 108.131 - y2: 138.971
#     Calculating Pair - 4 - 5 - y1: 128.131 - y2: 138.971
# Calculating File - alhic2302 - 17 - t - AC
#     Calculating Pair - 0 - 1 - y1: 60.144 - y2: 80.144
#     Calculating Pair - 0 - 2 - y1: 60.144 - y2: 100.144
#     Calculating Pair - 0 - 3 - y1: 60.144 - y2: 120.144
#     Calculating Pair - 0 - 4 - y1: 60.144 - y2: 140.144
#     Calculating Pair - 0 - 5 - y1: 60.144 - y2: 152.818
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 80.144 - y2: 100.144
#     Calculating Pair - 1 - 3 - y1: 80.144 - y2: 120.144
#     Calculating Pair - 1 - 4 - y1: 80.144 - y2: 140.144
#     Calculating Pair - 1 - 5 - y1: 80.144 - y2: 152.818
#     Calculating Pair - 2 - 3 - y1: 100.144 - y2: 120.144
#     Calculating Pair - 2 - 4 - y1: 100.144 - y2: 140.144
#     Calculating Pair - 2 - 5 - y1: 100.144 - y2: 152.818
#     Calculating Pair - 3 - 4 - y1: 120.144 - y2: 140.144
#     Calculating Pair - 3 - 5 - y1: 120.144 - y2: 152.818
#     Calculating Pair - 4 - 5 - y1: 140.144 - y2: 152.818
# Calculating File - alhic2302 - 18 - l - AC
#     Calculating Pair - 0 - 1 - y1: 70.577 - y2: 90.577
#     Calculating Pair - 0 - 2 - y1: 70.577 - y2: 110.577
#     Calculating Pair - 0 - 3 - y1: 70.577 - y2: 130.577
#     Calculating Pair - 0 - 4 - y1: 70.577 - y2: 150.577
#     Calculating Pair - 0 - 5 - y1: 70.577 - y2: 165.558
#     Calculating Pair - 1 - 2 - y1: 90.577 - y2: 110.577
#     Calculating Pair - 1 - 3 - y1: 90.577 - y2: 130.577
#     Calculating Pair - 1 - 4 - y1: 90.577 - y2: 150.577
#     Calculating Pair - 1 - 5 - y1: 90.577 - y2: 165.558
#     Calculating Pair - 2 - 3 - y1: 110.577 - y2: 130.577
#     Calculating Pair - 2 - 4 - y1: 110.577 - y2: 150.577
#     Calculating Pair - 2 - 5 - y1: 110.577 - y2: 165.558
#     Calculating Pair - 3 - 4 - y1: 130.577 - y2: 150.577
#     Calculating Pair - 3 - 5 - y1: 130.577 - y2: 165.558
#     Calculating Pair - 4 - 5 - y1: 150.577 - y2: 165.558
# Calculating File - alhic2302 - 18 - t - AC
#     Calculating Pair - 0 - 1 - y1: 84.321 - y2: 104.321
#     Calculating Pair - 0 - 2 - y1: 84.321 - y2: 124.321
#     Calculating Pair - 0 - 3 - y1: 84.321 - y2: 144.321
#     Calculating Pair - 0 - 4 - y1: 84.321 - y2: 164.321
#     Calculating Pair - 0 - 5 - y1: 84.321 - y2: 180.058
#     Calculating Pair - 1 - 2 - y1: 104.321 - y2: 124.321
#     Calculating Pair - 1 - 3 - y1: 104.321 - y2: 144.321
#     Calculating Pair - 1 - 4 - y1: 104.321 - y2: 164.321
#     Calculating Pair - 1 - 5 - y1: 104.321 - y2: 180.058
#     Calculating Pair - 2 - 3 - y1: 124.321 - y2: 144.321
#     Calculating Pair - 2 - 4 - y1: 124.321 - y2: 164.321
#     Calculating Pair - 2 - 5 - y1: 124.321 - y2: 180.058
#     Calculating Pair - 3 - 4 - y1: 144.321 - y2: 164.321
#     Calculating Pair - 3 - 5 - y1: 144.321 - y2: 180.058
#     Calculating Pair - 4 - 5 - y1: 164.321 - y2: 180.058
# Calculating File - alhic2302 - 19 - l - AC
#     Calculating Pair - 0 - 1 - y1: 64.077 - y2: 84.077
#     Calculating Pair - 0 - 2 - y1: 64.077 - y2: 104.077
#     Calculating Pair - 0 - 3 - y1: 64.077 - y2: 124.077
#     Calculating Pair - 0 - 4 - y1: 64.077 - y2: 144.077
#     Calculating Pair - 1 - 2 - y1: 84.077 - y2: 104.077
#     Calculating Pair - 1 - 3 - y1: 84.077 - y2: 124.077
#     Calculating Pair - 1 - 4 - y1: 84.077 - y2: 144.077
#     Calculating Pair - 2 - 3 - y1: 104.077 - y2: 124.077
#     Calculating Pair - 2 - 4 - y1: 104.077 - y2: 144.077
#     Calculating Pair - 3 - 4 - y1: 124.077 - y2: 144.077
# Calculating File - alhic2302 - 19 - t - AC
#     Calculating Pair - 0 - 1 - y1: 55.128 - y2: 75.128
#     Calculating Pair - 0 - 2 - y1: 55.128 - y2: 95.128
#     Calculating Pair - 0 - 3 - y1: 55.128 - y2: 115.128
#     Calculating Pair - 0 - 4 - y1: 55.128 - y2: 135.128
#     Calculating Pair - 0 - 5 - y1: 55.128 - y2: 149.972
#     Calculating Pair - 1 - 2 - y1: 75.128 - y2: 95.128
#     Calculating Pair - 1 - 3 - y1: 75.128 - y2: 115.128
#     Calculating Pair - 1 - 4 - y1: 75.128 - y2: 135.128
#     Calculating Pair - 1 - 5 - y1: 75.128 - y2: 149.972
#     Calculating Pair - 2 - 3 - y1: 95.128 - y2: 115.128
#     Calculating Pair - 2 - 4 - y1: 95.128 - y2: 135.128
#     Calculating Pair - 2 - 5 - y1: 95.128 - y2: 149.972
#     Calculating Pair - 3 - 4 - y1: 115.128 - y2: 135.128
#     Calculating Pair - 3 - 5 - y1: 115.128 - y2: 149.972
#     Calculating Pair - 4 - 5 - y1: 135.128 - y2: 149.972
# Calculating File - alhic2302 - 20 - l - AC
#     Calculating Pair - 0 - 1 - y1: 63.392 - y2: 83.392
#     Calculating Pair - 0 - 2 - y1: 63.392 - y2: 103.392
#     Calculating Pair - 0 - 3 - y1: 63.392 - y2: 123.392
#         Not enough common depths for pair
#     Calculating Pair - 0 - 4 - y1: 63.392 - y2: 143.392
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 63.392 - y2: 150.301
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 83.392 - y2: 103.392
#     Calculating Pair - 1 - 3 - y1: 83.392 - y2: 123.392
#     Calculating Pair - 1 - 4 - y1: 83.392 - y2: 143.392
#         Not enough common depths for pair
#     Calculating Pair - 1 - 5 - y1: 83.392 - y2: 150.301
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 103.392 - y2: 123.392
#     Calculating Pair - 2 - 4 - y1: 103.392 - y2: 143.392
#     Calculating Pair - 2 - 5 - y1: 103.392 - y2: 150.301
#     Calculating Pair - 3 - 4 - y1: 123.392 - y2: 143.392
#     Calculating Pair - 3 - 5 - y1: 123.392 - y2: 150.301
#     Calculating Pair - 4 - 5 - y1: 143.392 - y2: 150.301
# Calculating File - alhic2302 - 20 - t - AC
#     Calculating Pair - 0 - 1 - y1: 57.138 - y2: 77.138
#     Calculating Pair - 0 - 2 - y1: 57.138 - y2: 97.138
#     Calculating Pair - 0 - 3 - y1: 57.138 - y2: 117.138
#         Not enough common depths for pair
#     Calculating Pair - 0 - 4 - y1: 57.138 - y2: 137.138
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 57.138 - y2: 152.597
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 77.138 - y2: 97.138
#     Calculating Pair - 1 - 3 - y1: 77.138 - y2: 117.138
#     Calculating Pair - 1 - 4 - y1: 77.138 - y2: 137.138
#         Not enough common depths for pair
#     Calculating Pair - 1 - 5 - y1: 77.138 - y2: 152.597
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 97.138 - y2: 117.138
#     Calculating Pair - 2 - 4 - y1: 97.138 - y2: 137.138
#     Calculating Pair - 2 - 5 - y1: 97.138 - y2: 152.597
#         Not enough common depths for pair
#     Calculating Pair - 3 - 4 - y1: 117.138 - y2: 137.138
#     Calculating Pair - 3 - 5 - y1: 117.138 - y2: 152.597
#     Calculating Pair - 4 - 5 - y1: 137.138 - y2: 152.597
# Calculating File - alhic2302 - 21 - l - AC
#     Calculating Pair - 0 - 1 - y1: 60.543 - y2: 80.543
#     Calculating Pair - 0 - 2 - y1: 60.543 - y2: 100.543
#     Calculating Pair - 0 - 3 - y1: 60.543 - y2: 120.543
#     Calculating Pair - 0 - 4 - y1: 60.543 - y2: 140.543
#     Calculating Pair - 0 - 5 - y1: 60.543 - y2: 148.21
#     Calculating Pair - 1 - 2 - y1: 80.543 - y2: 100.543
#     Calculating Pair - 1 - 3 - y1: 80.543 - y2: 120.543
#     Calculating Pair - 1 - 4 - y1: 80.543 - y2: 140.543
#     Calculating Pair - 1 - 5 - y1: 80.543 - y2: 148.21
#     Calculating Pair - 2 - 3 - y1: 100.543 - y2: 120.543
#     Calculating Pair - 2 - 4 - y1: 100.543 - y2: 140.543
#     Calculating Pair - 2 - 5 - y1: 100.543 - y2: 148.21
#     Calculating Pair - 3 - 4 - y1: 120.543 - y2: 140.543
#     Calculating Pair - 3 - 5 - y1: 120.543 - y2: 148.21
#     Calculating Pair - 4 - 5 - y1: 140.543 - y2: 148.21
# Calculating File - alhic2302 - 21 - t - AC
#     Calculating Pair - 0 - 1 - y1: 57.092 - y2: 77.092
#     Calculating Pair - 0 - 2 - y1: 57.092 - y2: 97.092
#     Calculating Pair - 0 - 3 - y1: 57.092 - y2: 117.092
#     Calculating Pair - 0 - 4 - y1: 57.092 - y2: 137.092
#     Calculating Pair - 0 - 5 - y1: 57.092 - y2: 152.009
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 77.092 - y2: 97.092
#     Calculating Pair - 1 - 3 - y1: 77.092 - y2: 117.092
#     Calculating Pair - 1 - 4 - y1: 77.092 - y2: 137.092
#     Calculating Pair - 1 - 5 - y1: 77.092 - y2: 152.009
#     Calculating Pair - 2 - 3 - y1: 97.092 - y2: 117.092
#     Calculating Pair - 2 - 4 - y1: 97.092 - y2: 137.092
#     Calculating Pair - 2 - 5 - y1: 97.092 - y2: 152.009
#     Calculating Pair - 3 - 4 - y1: 117.092 - y2: 137.092
#     Calculating Pair - 3 - 5 - y1: 117.092 - y2: 152.009
#     Calculating Pair - 4 - 5 - y1: 137.092 - y2: 152.009
# Calculating File - alhic2302 - 22 - l - AC
#     Calculating Pair - 0 - 1 - y1: 61.28 - y2: 81.28
#     Calculating Pair - 0 - 2 - y1: 61.28 - y2: 101.28
#     Calculating Pair - 0 - 3 - y1: 61.28 - y2: 121.28
#     Calculating Pair - 0 - 4 - y1: 61.28 - y2: 141.28
#     Calculating Pair - 0 - 5 - y1: 61.28 - y2: 150.902
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 81.28 - y2: 101.28
#     Calculating Pair - 1 - 3 - y1: 81.28 - y2: 121.28
#     Calculating Pair - 1 - 4 - y1: 81.28 - y2: 141.28
#     Calculating Pair - 1 - 5 - y1: 81.28 - y2: 150.902
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 101.28 - y2: 121.28
#     Calculating Pair - 2 - 4 - y1: 101.28 - y2: 141.28
#     Calculating Pair - 2 - 5 - y1: 101.28 - y2: 150.902
#     Calculating Pair - 3 - 4 - y1: 121.28 - y2: 141.28
#     Calculating Pair - 3 - 5 - y1: 121.28 - y2: 150.902
#     Calculating Pair - 4 - 5 - y1: 141.28 - y2: 150.902
# Calculating File - alhic2302 - 22 - t - AC
#     Calculating Pair - 0 - 1 - y1: 51.705 - y2: 71.705
#     Calculating Pair - 0 - 2 - y1: 51.705 - y2: 91.705
#     Calculating Pair - 0 - 3 - y1: 51.705 - y2: 111.705
#         Not enough common depths for pair
#     Calculating Pair - 0 - 4 - y1: 51.705 - y2: 131.705
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 51.705 - y2: 148.207
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 71.705 - y2: 91.705
#     Calculating Pair - 1 - 3 - y1: 71.705 - y2: 111.705
#     Calculating Pair - 1 - 4 - y1: 71.705 - y2: 131.705
#         Not enough common depths for pair
#     Calculating Pair - 1 - 5 - y1: 71.705 - y2: 148.207
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 91.705 - y2: 111.705
#     Calculating Pair - 2 - 4 - y1: 91.705 - y2: 131.705
#     Calculating Pair - 2 - 5 - y1: 91.705 - y2: 148.207
#         Not enough common depths for pair
#     Calculating Pair - 3 - 4 - y1: 111.705 - y2: 131.705
#     Calculating Pair - 3 - 5 - y1: 111.705 - y2: 148.207
#     Calculating Pair - 4 - 5 - y1: 131.705 - y2: 148.207
# Calculating File - alhic2302 - 22 - t - AC
#     Calculating Pair - 0 - 1 - y1: 51.705 - y2: 71.705
#     Calculating Pair - 0 - 2 - y1: 51.705 - y2: 91.705
#     Calculating Pair - 0 - 3 - y1: 51.705 - y2: 111.705
#         Not enough common depths for pair
#     Calculating Pair - 0 - 4 - y1: 51.705 - y2: 131.705
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 51.705 - y2: 148.207
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 71.705 - y2: 91.705
#     Calculating Pair - 1 - 3 - y1: 71.705 - y2: 111.705
#     Calculating Pair - 1 - 4 - y1: 71.705 - y2: 131.705
#         Not enough common depths for pair
#     Calculating Pair - 1 - 5 - y1: 71.705 - y2: 148.207
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 91.705 - y2: 111.705
#     Calculating Pair - 2 - 4 - y1: 91.705 - y2: 131.705
#     Calculating Pair - 2 - 5 - y1: 91.705 - y2: 148.207
#         Not enough common depths for pair
#     Calculating Pair - 3 - 4 - y1: 111.705 - y2: 131.705
#     Calculating Pair - 3 - 5 - y1: 111.705 - y2: 148.207
#     Calculating Pair - 4 - 5 - y1: 131.705 - y2: 148.207
# Calculating File - alhic2302 - 23 - l - AC
#     Calculating Pair - 0 - 1 - y1: 53.61 - y2: 73.61
#     Calculating Pair - 0 - 2 - y1: 53.61 - y2: 93.61
#     Calculating Pair - 0 - 3 - y1: 53.61 - y2: 113.61
#     Calculating Pair - 0 - 4 - y1: 53.61 - y2: 133.61
#     Calculating Pair - 0 - 5 - y1: 53.61 - y2: 147.021
#     Calculating Pair - 1 - 2 - y1: 73.61 - y2: 93.61
#     Calculating Pair - 1 - 3 - y1: 73.61 - y2: 113.61
#     Calculating Pair - 1 - 4 - y1: 73.61 - y2: 133.61
#     Calculating Pair - 1 - 5 - y1: 73.61 - y2: 147.021
#     Calculating Pair - 2 - 3 - y1: 93.61 - y2: 113.61
#     Calculating Pair - 2 - 4 - y1: 93.61 - y2: 133.61
#     Calculating Pair - 2 - 5 - y1: 93.61 - y2: 147.021
#     Calculating Pair - 3 - 4 - y1: 113.61 - y2: 133.61
#     Calculating Pair - 3 - 5 - y1: 113.61 - y2: 147.021
#     Calculating Pair - 4 - 5 - y1: 133.61 - y2: 147.021
# Calculating File - alhic2302 - 23 - t - AC
#     Calculating Pair - 0 - 1 - y1: 52.204 - y2: 72.204
#     Calculating Pair - 0 - 2 - y1: 52.204 - y2: 92.204
#     Calculating Pair - 0 - 3 - y1: 52.204 - y2: 112.204
#     Calculating Pair - 0 - 4 - y1: 52.204 - y2: 132.204
#     Calculating Pair - 0 - 5 - y1: 52.204 - y2: 149.37
#     Calculating Pair - 1 - 2 - y1: 72.204 - y2: 92.204
#     Calculating Pair - 1 - 3 - y1: 72.204 - y2: 112.204
#     Calculating Pair - 1 - 4 - y1: 72.204 - y2: 132.204
#     Calculating Pair - 1 - 5 - y1: 72.204 - y2: 149.37
#     Calculating Pair - 2 - 3 - y1: 92.204 - y2: 112.204
#     Calculating Pair - 2 - 4 - y1: 92.204 - y2: 132.204
#     Calculating Pair - 2 - 5 - y1: 92.204 - y2: 149.37
#     Calculating Pair - 3 - 4 - y1: 112.204 - y2: 132.204
#     Calculating Pair - 3 - 5 - y1: 112.204 - y2: 149.37
#     Calculating Pair - 4 - 5 - y1: 132.204 - y2: 149.37
# Calculating File - alhic2302 - 24 - l - AC
#     Calculating Pair - 0 - 1 - y1: 56.846 - y2: 76.846
#     Calculating Pair - 0 - 2 - y1: 56.846 - y2: 96.846
#     Calculating Pair - 0 - 3 - y1: 56.846 - y2: 116.846
#     Calculating Pair - 0 - 4 - y1: 56.846 - y2: 136.846
#     Calculating Pair - 0 - 5 - y1: 56.846 - y2: 149.737
#     Calculating Pair - 1 - 2 - y1: 76.846 - y2: 96.846
#     Calculating Pair - 1 - 3 - y1: 76.846 - y2: 116.846
#     Calculating Pair - 1 - 4 - y1: 76.846 - y2: 136.846
#     Calculating Pair - 1 - 5 - y1: 76.846 - y2: 149.737
#     Calculating Pair - 2 - 3 - y1: 96.846 - y2: 116.846
#     Calculating Pair - 2 - 4 - y1: 96.846 - y2: 136.846
#     Calculating Pair - 2 - 5 - y1: 96.846 - y2: 149.737
#     Calculating Pair - 3 - 4 - y1: 116.846 - y2: 136.846
#     Calculating Pair - 3 - 5 - y1: 116.846 - y2: 149.737
#     Calculating Pair - 4 - 5 - y1: 136.846 - y2: 149.737
# Calculating File - alhic2302 - 24 - t - AC
#     Calculating Pair - 0 - 1 - y1: 49.608 - y2: 69.608
#     Calculating Pair - 0 - 2 - y1: 49.608 - y2: 89.608
#     Calculating Pair - 0 - 3 - y1: 49.608 - y2: 109.608
#     Calculating Pair - 0 - 4 - y1: 49.608 - y2: 129.608
#     Calculating Pair - 0 - 5 - y1: 49.608 - y2: 149.608
#     Calculating Pair - 0 - 6 - y1: 49.608 - y2: 151.322
#     Calculating Pair - 1 - 2 - y1: 69.608 - y2: 89.608
#     Calculating Pair - 1 - 3 - y1: 69.608 - y2: 109.608
#     Calculating Pair - 1 - 4 - y1: 69.608 - y2: 129.608
#     Calculating Pair - 1 - 5 - y1: 69.608 - y2: 149.608
#     Calculating Pair - 1 - 6 - y1: 69.608 - y2: 151.322
#     Calculating Pair - 2 - 3 - y1: 89.608 - y2: 109.608
#     Calculating Pair - 2 - 4 - y1: 89.608 - y2: 129.608
#     Calculating Pair - 2 - 5 - y1: 89.608 - y2: 149.608
#     Calculating Pair - 2 - 6 - y1: 89.608 - y2: 151.322
#     Calculating Pair - 3 - 4 - y1: 109.608 - y2: 129.608
#     Calculating Pair - 3 - 5 - y1: 109.608 - y2: 149.608
#     Calculating Pair - 3 - 6 - y1: 109.608 - y2: 151.322
#     Calculating Pair - 4 - 5 - y1: 129.608 - y2: 149.608
#     Calculating Pair - 4 - 6 - y1: 129.608 - y2: 151.322
#     Calculating Pair - 5 - 6 - y1: 149.608 - y2: 151.322
#         Not enough separation between tracks for pair
# Calculating File - alhic2302 - 25 - l - AC
#     Calculating Pair - 0 - 1 - y1: 55.191 - y2: 75.191
#     Calculating Pair - 0 - 2 - y1: 55.191 - y2: 95.191
#     Calculating Pair - 0 - 3 - y1: 55.191 - y2: 115.191
#     Calculating Pair - 0 - 4 - y1: 55.191 - y2: 135.191
#     Calculating Pair - 0 - 5 - y1: 55.191 - y2: 147.933
#     Calculating Pair - 1 - 2 - y1: 75.191 - y2: 95.191
#     Calculating Pair - 1 - 3 - y1: 75.191 - y2: 115.191
#     Calculating Pair - 1 - 4 - y1: 75.191 - y2: 135.191
#     Calculating Pair - 1 - 5 - y1: 75.191 - y2: 147.933
#     Calculating Pair - 2 - 3 - y1: 95.191 - y2: 115.191
#     Calculating Pair - 2 - 4 - y1: 95.191 - y2: 135.191
#     Calculating Pair - 2 - 5 - y1: 95.191 - y2: 147.933
#     Calculating Pair - 3 - 4 - y1: 115.191 - y2: 135.191
#     Calculating Pair - 3 - 5 - y1: 115.191 - y2: 147.933
#     Calculating Pair - 4 - 5 - y1: 135.191 - y2: 147.933
# Calculating File - alhic2302 - 25 - t - AC
#     Calculating Pair - 0 - 1 - y1: 50.985 - y2: 70.985
#     Calculating Pair - 0 - 2 - y1: 50.985 - y2: 90.985
#     Calculating Pair - 0 - 3 - y1: 50.985 - y2: 110.985
#     Calculating Pair - 0 - 4 - y1: 50.985 - y2: 130.985
#     Calculating Pair - 0 - 5 - y1: 50.985 - y2: 149.258
#     Calculating Pair - 1 - 2 - y1: 70.985 - y2: 90.985
#     Calculating Pair - 1 - 3 - y1: 70.985 - y2: 110.985
#     Calculating Pair - 1 - 4 - y1: 70.985 - y2: 130.985
#     Calculating Pair - 1 - 5 - y1: 70.985 - y2: 149.258
#     Calculating Pair - 2 - 3 - y1: 90.985 - y2: 110.985
#     Calculating Pair - 2 - 4 - y1: 90.985 - y2: 130.985
#     Calculating Pair - 2 - 5 - y1: 90.985 - y2: 149.258
#     Calculating Pair - 3 - 4 - y1: 110.985 - y2: 130.985
#     Calculating Pair - 3 - 5 - y1: 110.985 - y2: 149.258
#     Calculating Pair - 4 - 5 - y1: 130.985 - y2: 149.258
# Calculating File - alhic2302 - 26 - l - AC
#     Calculating Pair - 0 - 1 - y1: 56.2 - y2: 76.2
#     Calculating Pair - 0 - 2 - y1: 56.2 - y2: 96.2
#     Calculating Pair - 0 - 3 - y1: 56.2 - y2: 116.2
#     Calculating Pair - 0 - 4 - y1: 56.2 - y2: 136.2
#     Calculating Pair - 0 - 5 - y1: 56.2 - y2: 147.332
#     Calculating Pair - 1 - 2 - y1: 76.2 - y2: 96.2
#     Calculating Pair - 1 - 3 - y1: 76.2 - y2: 116.2
#     Calculating Pair - 1 - 4 - y1: 76.2 - y2: 136.2
#     Calculating Pair - 1 - 5 - y1: 76.2 - y2: 147.332
#     Calculating Pair - 2 - 3 - y1: 96.2 - y2: 116.2
#     Calculating Pair - 2 - 4 - y1: 96.2 - y2: 136.2
#     Calculating Pair - 2 - 5 - y1: 96.2 - y2: 147.332
#     Calculating Pair - 3 - 4 - y1: 116.2 - y2: 136.2
#     Calculating Pair - 3 - 5 - y1: 116.2 - y2: 147.332
#     Calculating Pair - 4 - 5 - y1: 136.2 - y2: 147.332
# Calculating File - alhic2302 - 26 - t - AC
#     Calculating Pair - 0 - 1 - y1: 53.162 - y2: 73.162
#     Calculating Pair - 0 - 2 - y1: 53.162 - y2: 93.162
#     Calculating Pair - 0 - 3 - y1: 53.162 - y2: 113.162
#     Calculating Pair - 0 - 4 - y1: 53.162 - y2: 133.162
#     Calculating Pair - 0 - 5 - y1: 53.162 - y2: 153.162
#     Calculating Pair - 0 - 6 - y1: 53.162 - y2: 154.865
#     Calculating Pair - 1 - 2 - y1: 73.162 - y2: 93.162
#     Calculating Pair - 1 - 3 - y1: 73.162 - y2: 113.162
#     Calculating Pair - 1 - 4 - y1: 73.162 - y2: 133.162
#     Calculating Pair - 1 - 5 - y1: 73.162 - y2: 153.162
#     Calculating Pair - 1 - 6 - y1: 73.162 - y2: 154.865
#     Calculating Pair - 2 - 3 - y1: 93.162 - y2: 113.162
#     Calculating Pair - 2 - 4 - y1: 93.162 - y2: 133.162
#     Calculating Pair - 2 - 5 - y1: 93.162 - y2: 153.162
#     Calculating Pair - 2 - 6 - y1: 93.162 - y2: 154.865
#     Calculating Pair - 3 - 4 - y1: 113.162 - y2: 133.162
#     Calculating Pair - 3 - 5 - y1: 113.162 - y2: 153.162
#     Calculating Pair - 3 - 6 - y1: 113.162 - y2: 154.865
#     Calculating Pair - 4 - 5 - y1: 133.162 - y2: 153.162
#     Calculating Pair - 4 - 6 - y1: 133.162 - y2: 154.865
#     Calculating Pair - 5 - 6 - y1: 153.162 - y2: 154.865
#         Not enough separation between tracks for pair
# Calculating File - alhic2302 - 27 - l - AC
#     Calculating Pair - 0 - 1 - y1: 55.231 - y2: 75.231
#     Calculating Pair - 0 - 2 - y1: 55.231 - y2: 95.231
#     Calculating Pair - 0 - 3 - y1: 55.231 - y2: 115.231
#     Calculating Pair - 0 - 4 - y1: 55.231 - y2: 135.231
#     Calculating Pair - 0 - 5 - y1: 55.231 - y2: 146.379
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 75.231 - y2: 95.231
#     Calculating Pair - 1 - 3 - y1: 75.231 - y2: 115.231
#     Calculating Pair - 1 - 4 - y1: 75.231 - y2: 135.231
#     Calculating Pair - 1 - 5 - y1: 75.231 - y2: 146.379
#     Calculating Pair - 2 - 3 - y1: 95.231 - y2: 115.231
#     Calculating Pair - 2 - 4 - y1: 95.231 - y2: 135.231
#     Calculating Pair - 2 - 5 - y1: 95.231 - y2: 146.379
#     Calculating Pair - 3 - 4 - y1: 115.231 - y2: 135.231
#     Calculating Pair - 3 - 5 - y1: 115.231 - y2: 146.379
#     Calculating Pair - 4 - 5 - y1: 135.231 - y2: 146.379
# Calculating File - alhic2302 - 27 - t - AC
#     Calculating Pair - 0 - 1 - y1: 52.888 - y2: 72.888
#     Calculating Pair - 0 - 2 - y1: 52.888 - y2: 92.888
#     Calculating Pair - 0 - 3 - y1: 52.888 - y2: 112.888
#     Calculating Pair - 0 - 4 - y1: 52.888 - y2: 132.888
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 52.888 - y2: 150.791
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 72.888 - y2: 92.888
#     Calculating Pair - 1 - 3 - y1: 72.888 - y2: 112.888
#     Calculating Pair - 1 - 4 - y1: 72.888 - y2: 132.888
#     Calculating Pair - 1 - 5 - y1: 72.888 - y2: 150.791
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 92.888 - y2: 112.888
#     Calculating Pair - 2 - 4 - y1: 92.888 - y2: 132.888
#     Calculating Pair - 2 - 5 - y1: 92.888 - y2: 150.791
#     Calculating Pair - 3 - 4 - y1: 112.888 - y2: 132.888
#     Calculating Pair - 3 - 5 - y1: 112.888 - y2: 150.791
#     Calculating Pair - 4 - 5 - y1: 132.888 - y2: 150.791
# Calculating File - alhic2302 - 28 - l - AC
#     Calculating Pair - 0 - 1 - y1: 53.682 - y2: 73.682
#         Not enough common depths for pair
#     Calculating Pair - 0 - 2 - y1: 53.682 - y2: 93.682
#         Not enough common depths for pair
#     Calculating Pair - 0 - 3 - y1: 53.682 - y2: 113.682
#         Not enough common depths for pair
#     Calculating Pair - 0 - 4 - y1: 53.682 - y2: 133.682
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 53.682 - y2: 147.198
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 73.682 - y2: 93.682
#     Calculating Pair - 1 - 3 - y1: 73.682 - y2: 113.682
#     Calculating Pair - 1 - 4 - y1: 73.682 - y2: 133.682
#     Calculating Pair - 1 - 5 - y1: 73.682 - y2: 147.198
#     Calculating Pair - 2 - 3 - y1: 93.682 - y2: 113.682
#     Calculating Pair - 2 - 4 - y1: 93.682 - y2: 133.682
#     Calculating Pair - 2 - 5 - y1: 93.682 - y2: 147.198
#     Calculating Pair - 3 - 4 - y1: 113.682 - y2: 133.682
#     Calculating Pair - 3 - 5 - y1: 113.682 - y2: 147.198
#     Calculating Pair - 4 - 5 - y1: 133.682 - y2: 147.198
# Calculating File - alhic2302 - 28 - t - AC
#     Calculating Pair - 0 - 1 - y1: 49.898 - y2: 69.898
#     Calculating Pair - 0 - 2 - y1: 49.898 - y2: 89.898
#     Calculating Pair - 0 - 3 - y1: 49.898 - y2: 109.898
#     Calculating Pair - 0 - 4 - y1: 49.898 - y2: 129.898
#     Calculating Pair - 0 - 5 - y1: 49.898 - y2: 149.255
#     Calculating Pair - 1 - 2 - y1: 69.898 - y2: 89.898
#     Calculating Pair - 1 - 3 - y1: 69.898 - y2: 109.898
#     Calculating Pair - 1 - 4 - y1: 69.898 - y2: 129.898
#     Calculating Pair - 1 - 5 - y1: 69.898 - y2: 149.255
#     Calculating Pair - 2 - 3 - y1: 89.898 - y2: 109.898
#     Calculating Pair - 2 - 4 - y1: 89.898 - y2: 129.898
#     Calculating Pair - 2 - 5 - y1: 89.898 - y2: 149.255
#     Calculating Pair - 3 - 4 - y1: 109.898 - y2: 129.898
#     Calculating Pair - 3 - 5 - y1: 109.898 - y2: 149.255
#     Calculating Pair - 4 - 5 - y1: 129.898 - y2: 149.255
# Calculating File - alhic2302 - 29 - l - AC
#     Calculating Pair - 0 - 1 - y1: 57.162 - y2: 77.162
#     Calculating Pair - 0 - 2 - y1: 57.162 - y2: 97.162
#     Calculating Pair - 0 - 3 - y1: 57.162 - y2: 117.162
#     Calculating Pair - 0 - 4 - y1: 57.162 - y2: 137.162
#     Calculating Pair - 0 - 5 - y1: 57.162 - y2: 150.018
#     Calculating Pair - 1 - 2 - y1: 77.162 - y2: 97.162
#     Calculating Pair - 1 - 3 - y1: 77.162 - y2: 117.162
#     Calculating Pair - 1 - 4 - y1: 77.162 - y2: 137.162
#     Calculating Pair - 1 - 5 - y1: 77.162 - y2: 150.018
#     Calculating Pair - 2 - 3 - y1: 97.162 - y2: 117.162
#     Calculating Pair - 2 - 4 - y1: 97.162 - y2: 137.162
#     Calculating Pair - 2 - 5 - y1: 97.162 - y2: 150.018
#     Calculating Pair - 3 - 4 - y1: 117.162 - y2: 137.162
#     Calculating Pair - 3 - 5 - y1: 117.162 - y2: 150.018
#     Calculating Pair - 4 - 5 - y1: 137.162 - y2: 150.018
# Calculating File - alhic2302 - 29 - t - AC
#     Calculating Pair - 0 - 1 - y1: 51.425 - y2: 71.425
#     Calculating Pair - 0 - 2 - y1: 51.425 - y2: 91.425
#     Calculating Pair - 0 - 3 - y1: 51.425 - y2: 111.425
#     Calculating Pair - 0 - 4 - y1: 51.425 - y2: 131.425
#     Calculating Pair - 0 - 5 - y1: 51.425 - y2: 149.074
#     Calculating Pair - 1 - 2 - y1: 71.425 - y2: 91.425
#     Calculating Pair - 1 - 3 - y1: 71.425 - y2: 111.425
#     Calculating Pair - 1 - 4 - y1: 71.425 - y2: 131.425
#     Calculating Pair - 1 - 5 - y1: 71.425 - y2: 149.074
#     Calculating Pair - 2 - 3 - y1: 91.425 - y2: 111.425
#     Calculating Pair - 2 - 4 - y1: 91.425 - y2: 131.425
#     Calculating Pair - 2 - 5 - y1: 91.425 - y2: 149.074
#     Calculating Pair - 3 - 4 - y1: 111.425 - y2: 131.425
#     Calculating Pair - 3 - 5 - y1: 111.425 - y2: 149.074
#     Calculating Pair - 4 - 5 - y1: 131.425 - y2: 149.074
# Calculating File - alhic2302 - 30 - l - AC
#     Calculating Pair - 0 - 1 - y1: 52.06 - y2: 72.06
#     Calculating Pair - 0 - 2 - y1: 52.06 - y2: 92.06
#     Calculating Pair - 0 - 3 - y1: 52.06 - y2: 112.06
#     Calculating Pair - 0 - 4 - y1: 52.06 - y2: 132.06
#     Calculating Pair - 0 - 5 - y1: 52.06 - y2: 147.933
#     Calculating Pair - 1 - 2 - y1: 72.06 - y2: 92.06
#     Calculating Pair - 1 - 3 - y1: 72.06 - y2: 112.06
#     Calculating Pair - 1 - 4 - y1: 72.06 - y2: 132.06
#     Calculating Pair - 1 - 5 - y1: 72.06 - y2: 147.933
#     Calculating Pair - 2 - 3 - y1: 92.06 - y2: 112.06
#     Calculating Pair - 2 - 4 - y1: 92.06 - y2: 132.06
#     Calculating Pair - 2 - 5 - y1: 92.06 - y2: 147.933
#     Calculating Pair - 3 - 4 - y1: 112.06 - y2: 132.06
#     Calculating Pair - 3 - 5 - y1: 112.06 - y2: 147.933
#     Calculating Pair - 4 - 5 - y1: 132.06 - y2: 147.933
# Calculating File - alhic2302 - 30 - t - AC
#     Calculating Pair - 0 - 1 - y1: 48.596 - y2: 68.596
#     Calculating Pair - 0 - 2 - y1: 48.596 - y2: 88.596
#     Calculating Pair - 0 - 3 - y1: 48.596 - y2: 108.596
#     Calculating Pair - 0 - 4 - y1: 48.596 - y2: 128.596
#     Calculating Pair - 0 - 5 - y1: 48.596 - y2: 147.812
#     Calculating Pair - 1 - 2 - y1: 68.596 - y2: 88.596
#     Calculating Pair - 1 - 3 - y1: 68.596 - y2: 108.596
#     Calculating Pair - 1 - 4 - y1: 68.596 - y2: 128.596
#     Calculating Pair - 1 - 5 - y1: 68.596 - y2: 147.812
#     Calculating Pair - 2 - 3 - y1: 88.596 - y2: 108.596
#     Calculating Pair - 2 - 4 - y1: 88.596 - y2: 128.596
#     Calculating Pair - 2 - 5 - y1: 88.596 - y2: 147.812
#     Calculating Pair - 3 - 4 - y1: 108.596 - y2: 128.596
#     Calculating Pair - 3 - 5 - y1: 108.596 - y2: 147.812
#     Calculating Pair - 4 - 5 - y1: 128.596 - y2: 147.812
# Calculating File - alhic2302 - 31 - l - AC
#     Calculating Pair - 0 - 1 - y1: 57.264 - y2: 77.264
#     Calculating Pair - 0 - 2 - y1: 57.264 - y2: 97.264
#     Calculating Pair - 0 - 3 - y1: 57.264 - y2: 117.264
#     Calculating Pair - 0 - 4 - y1: 57.264 - y2: 137.264
#     Calculating Pair - 0 - 5 - y1: 57.264 - y2: 146.179
#     Calculating Pair - 1 - 2 - y1: 77.264 - y2: 97.264
#     Calculating Pair - 1 - 3 - y1: 77.264 - y2: 117.264
#     Calculating Pair - 1 - 4 - y1: 77.264 - y2: 137.264
#     Calculating Pair - 1 - 5 - y1: 77.264 - y2: 146.179
#     Calculating Pair - 2 - 3 - y1: 97.264 - y2: 117.264
#     Calculating Pair - 2 - 4 - y1: 97.264 - y2: 137.264
#     Calculating Pair - 2 - 5 - y1: 97.264 - y2: 146.179
#     Calculating Pair - 3 - 4 - y1: 117.264 - y2: 137.264
#     Calculating Pair - 3 - 5 - y1: 117.264 - y2: 146.179
#     Calculating Pair - 4 - 5 - y1: 137.264 - y2: 146.179
# Calculating File - alhic2302 - 31 - t - AC
#     Calculating Pair - 0 - 1 - y1: 53.789 - y2: 73.789
#     Calculating Pair - 0 - 2 - y1: 53.789 - y2: 93.789
#     Calculating Pair - 0 - 3 - y1: 53.789 - y2: 113.789
#     Calculating Pair - 0 - 4 - y1: 53.789 - y2: 133.789
#     Calculating Pair - 0 - 5 - y1: 53.789 - y2: 149.601
#     Calculating Pair - 1 - 2 - y1: 73.789 - y2: 93.789
#     Calculating Pair - 1 - 3 - y1: 73.789 - y2: 113.789
#     Calculating Pair - 1 - 4 - y1: 73.789 - y2: 133.789
#     Calculating Pair - 1 - 5 - y1: 73.789 - y2: 149.601
#     Calculating Pair - 2 - 3 - y1: 93.789 - y2: 113.789
#     Calculating Pair - 2 - 4 - y1: 93.789 - y2: 133.789
#     Calculating Pair - 2 - 5 - y1: 93.789 - y2: 149.601
#     Calculating Pair - 3 - 4 - y1: 113.789 - y2: 133.789
#     Calculating Pair - 3 - 5 - y1: 113.789 - y2: 149.601
#     Calculating Pair - 4 - 5 - y1: 133.789 - y2: 149.601
# Calculating File - alhic2302 - 32 - l - AC
#     Calculating Pair - 0 - 1 - y1: 56.052 - y2: 76.052
#     Calculating Pair - 0 - 2 - y1: 56.052 - y2: 96.052
#     Calculating Pair - 0 - 3 - y1: 56.052 - y2: 116.052
#     Calculating Pair - 0 - 4 - y1: 56.052 - y2: 136.052
#     Calculating Pair - 0 - 5 - y1: 56.052 - y2: 146.948
#     Calculating Pair - 1 - 2 - y1: 76.052 - y2: 96.052
#     Calculating Pair - 1 - 3 - y1: 76.052 - y2: 116.052
#     Calculating Pair - 1 - 4 - y1: 76.052 - y2: 136.052
#     Calculating Pair - 1 - 5 - y1: 76.052 - y2: 146.948
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 96.052 - y2: 116.052
#     Calculating Pair - 2 - 4 - y1: 96.052 - y2: 136.052
#     Calculating Pair - 2 - 5 - y1: 96.052 - y2: 146.948
#     Calculating Pair - 3 - 4 - y1: 116.052 - y2: 136.052
#     Calculating Pair - 3 - 5 - y1: 116.052 - y2: 146.948
#     Calculating Pair - 4 - 5 - y1: 136.052 - y2: 146.948
# Calculating File - alhic2302 - 32 - t - AC
#     Calculating Pair - 0 - 1 - y1: 51.316 - y2: 71.316
#     Calculating Pair - 0 - 2 - y1: 51.316 - y2: 91.316
#     Calculating Pair - 0 - 3 - y1: 51.316 - y2: 111.316
#         Not enough common depths for pair
#     Calculating Pair - 0 - 4 - y1: 51.316 - y2: 131.316
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 51.316 - y2: 147.611
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 71.316 - y2: 91.316
#     Calculating Pair - 1 - 3 - y1: 71.316 - y2: 111.316
#     Calculating Pair - 1 - 4 - y1: 71.316 - y2: 131.316
#         Not enough common depths for pair
#     Calculating Pair - 1 - 5 - y1: 71.316 - y2: 147.611
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 91.316 - y2: 111.316
#     Calculating Pair - 2 - 4 - y1: 91.316 - y2: 131.316
#     Calculating Pair - 2 - 5 - y1: 91.316 - y2: 147.611
#         Not enough common depths for pair
#     Calculating Pair - 3 - 4 - y1: 111.316 - y2: 131.316
#     Calculating Pair - 3 - 5 - y1: 111.316 - y2: 147.611
#     Calculating Pair - 4 - 5 - y1: 131.316 - y2: 147.611
# Calculating File - alhic2302 - 33 - l - AC
#     Calculating Pair - 0 - 1 - y1: 57.52 - y2: 77.52
#     Calculating Pair - 0 - 2 - y1: 57.52 - y2: 97.52
#     Calculating Pair - 0 - 3 - y1: 57.52 - y2: 117.52
#     Calculating Pair - 0 - 4 - y1: 57.52 - y2: 137.52
#     Calculating Pair - 0 - 5 - y1: 57.52 - y2: 146.548
#     Calculating Pair - 1 - 2 - y1: 77.52 - y2: 97.52
#     Calculating Pair - 1 - 3 - y1: 77.52 - y2: 117.52
#     Calculating Pair - 1 - 4 - y1: 77.52 - y2: 137.52
#     Calculating Pair - 1 - 5 - y1: 77.52 - y2: 146.548
#     Calculating Pair - 2 - 3 - y1: 97.52 - y2: 117.52
#     Calculating Pair - 2 - 4 - y1: 97.52 - y2: 137.52
#     Calculating Pair - 2 - 5 - y1: 97.52 - y2: 146.548
#     Calculating Pair - 3 - 4 - y1: 117.52 - y2: 137.52
#     Calculating Pair - 3 - 5 - y1: 117.52 - y2: 146.548
#     Calculating Pair - 4 - 5 - y1: 137.52 - y2: 146.548
# Calculating File - alhic2302 - 33 - t - AC
#     Calculating Pair - 0 - 1 - y1: 49.059 - y2: 69.059
#     Calculating Pair - 0 - 2 - y1: 49.059 - y2: 89.059
#     Calculating Pair - 0 - 3 - y1: 49.059 - y2: 109.059
#     Calculating Pair - 0 - 4 - y1: 49.059 - y2: 129.059
#     Calculating Pair - 0 - 5 - y1: 49.059 - y2: 144.016
#     Calculating Pair - 1 - 2 - y1: 69.059 - y2: 89.059
#     Calculating Pair - 1 - 3 - y1: 69.059 - y2: 109.059
#     Calculating Pair - 1 - 4 - y1: 69.059 - y2: 129.059
#     Calculating Pair - 1 - 5 - y1: 69.059 - y2: 144.016
#     Calculating Pair - 2 - 3 - y1: 89.059 - y2: 109.059
#     Calculating Pair - 2 - 4 - y1: 89.059 - y2: 129.059
#     Calculating Pair - 2 - 5 - y1: 89.059 - y2: 144.016
#     Calculating Pair - 3 - 4 - y1: 109.059 - y2: 129.059
#     Calculating Pair - 3 - 5 - y1: 109.059 - y2: 144.016
#     Calculating Pair - 4 - 5 - y1: 129.059 - y2: 144.016
# Calculating File - alhic2302 - 34 - l - AC
#     Calculating Pair - 0 - 1 - y1: 52.69 - y2: 72.69
#     Calculating Pair - 0 - 2 - y1: 52.69 - y2: 92.69
#     Calculating Pair - 0 - 3 - y1: 52.69 - y2: 112.69
#     Calculating Pair - 0 - 4 - y1: 52.69 - y2: 132.69
#     Calculating Pair - 0 - 5 - y1: 52.69 - y2: 147.12
#     Calculating Pair - 1 - 2 - y1: 72.69 - y2: 92.69
#     Calculating Pair - 1 - 3 - y1: 72.69 - y2: 112.69
#     Calculating Pair - 1 - 4 - y1: 72.69 - y2: 132.69
#     Calculating Pair - 1 - 5 - y1: 72.69 - y2: 147.12
#     Calculating Pair - 2 - 3 - y1: 92.69 - y2: 112.69
#     Calculating Pair - 2 - 4 - y1: 92.69 - y2: 132.69
#     Calculating Pair - 2 - 5 - y1: 92.69 - y2: 147.12
#     Calculating Pair - 3 - 4 - y1: 112.69 - y2: 132.69
#     Calculating Pair - 3 - 5 - y1: 112.69 - y2: 147.12
#     Calculating Pair - 4 - 5 - y1: 132.69 - y2: 147.12
# Calculating File - alhic2302 - 34 - t - AC
#     Calculating Pair - 0 - 1 - y1: 52.387 - y2: 72.387
#     Calculating Pair - 0 - 2 - y1: 52.387 - y2: 92.387
#     Calculating Pair - 0 - 3 - y1: 52.387 - y2: 112.387
#     Calculating Pair - 0 - 4 - y1: 52.387 - y2: 132.387
#     Calculating Pair - 0 - 5 - y1: 52.387 - y2: 148.679
#     Calculating Pair - 1 - 2 - y1: 72.387 - y2: 92.387
#     Calculating Pair - 1 - 3 - y1: 72.387 - y2: 112.387
#     Calculating Pair - 1 - 4 - y1: 72.387 - y2: 132.387
#     Calculating Pair - 1 - 5 - y1: 72.387 - y2: 148.679
#     Calculating Pair - 2 - 3 - y1: 92.387 - y2: 112.387
#     Calculating Pair - 2 - 4 - y1: 92.387 - y2: 132.387
#     Calculating Pair - 2 - 5 - y1: 92.387 - y2: 148.679
#     Calculating Pair - 3 - 4 - y1: 112.387 - y2: 132.387
#     Calculating Pair - 3 - 5 - y1: 112.387 - y2: 148.679
#     Calculating Pair - 4 - 5 - y1: 132.387 - y2: 148.679
# Calculating File - alhic2302 - 35 - l - AC
#     Calculating Pair - 0 - 1 - y1: 56.704 - y2: 76.704
#     Calculating Pair - 0 - 2 - y1: 56.704 - y2: 96.704
#     Calculating Pair - 0 - 3 - y1: 56.704 - y2: 116.704
#     Calculating Pair - 0 - 4 - y1: 56.704 - y2: 136.704
#     Calculating Pair - 0 - 5 - y1: 56.704 - y2: 147.481
#     Calculating Pair - 1 - 2 - y1: 76.704 - y2: 96.704
#     Calculating Pair - 1 - 3 - y1: 76.704 - y2: 116.704
#     Calculating Pair - 1 - 4 - y1: 76.704 - y2: 136.704
#     Calculating Pair - 1 - 5 - y1: 76.704 - y2: 147.481
#     Calculating Pair - 2 - 3 - y1: 96.704 - y2: 116.704
#     Calculating Pair - 2 - 4 - y1: 96.704 - y2: 136.704
#     Calculating Pair - 2 - 5 - y1: 96.704 - y2: 147.481
#     Calculating Pair - 3 - 4 - y1: 116.704 - y2: 136.704
#     Calculating Pair - 3 - 5 - y1: 116.704 - y2: 147.481
#     Calculating Pair - 4 - 5 - y1: 136.704 - y2: 147.481
# Calculating File - alhic2302 - 35 - t - AC
#     Calculating Pair - 0 - 1 - y1: 51.823 - y2: 71.823
#     Calculating Pair - 0 - 2 - y1: 51.823 - y2: 91.823
#     Calculating Pair - 0 - 3 - y1: 51.823 - y2: 111.823
#     Calculating Pair - 0 - 4 - y1: 51.823 - y2: 131.823
#     Calculating Pair - 0 - 5 - y1: 51.823 - y2: 148.327
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 71.823 - y2: 91.823
#     Calculating Pair - 1 - 3 - y1: 71.823 - y2: 111.823
#     Calculating Pair - 1 - 4 - y1: 71.823 - y2: 131.823
#     Calculating Pair - 1 - 5 - y1: 71.823 - y2: 148.327
#     Calculating Pair - 2 - 3 - y1: 91.823 - y2: 111.823
#     Calculating Pair - 2 - 4 - y1: 91.823 - y2: 131.823
#     Calculating Pair - 2 - 5 - y1: 91.823 - y2: 148.327
#     Calculating Pair - 3 - 4 - y1: 111.823 - y2: 131.823
#     Calculating Pair - 3 - 5 - y1: 111.823 - y2: 148.327
#     Calculating Pair - 4 - 5 - y1: 131.823 - y2: 148.327
# Calculating File - alhic2302 - 36 - l - AC
#     Calculating Pair - 0 - 1 - y1: 55.075 - y2: 75.075
#     Calculating Pair - 0 - 2 - y1: 55.075 - y2: 95.075
#     Calculating Pair - 0 - 3 - y1: 55.075 - y2: 115.075
#     Calculating Pair - 0 - 4 - y1: 55.075 - y2: 135.075
#     Calculating Pair - 0 - 5 - y1: 55.075 - y2: 146.483
#     Calculating Pair - 1 - 2 - y1: 75.075 - y2: 95.075
#     Calculating Pair - 1 - 3 - y1: 75.075 - y2: 115.075
#     Calculating Pair - 1 - 4 - y1: 75.075 - y2: 135.075
#     Calculating Pair - 1 - 5 - y1: 75.075 - y2: 146.483
# ...
#     Calculating Pair - 0 - 2 - y1: 52.302 - y2: 92.302
#     Calculating Pair - 0 - 3 - y1: 52.302 - y2: 112.302
#     Calculating Pair - 0 - 4 - y1: 52.302 - y2: 132.302
#     Calculating Pair - 0 - 5 - y1: 52.302 - y2: 144.624
#     Calculating Pair - 1 - 2 - y1: 72.302 - y2: 92.302
#     Calculating Pair - 1 - 3 - y1: 72.302 - y2: 112.302
#     Calculating Pair - 1 - 4 - y1: 72.302 - y2: 132.302
#     Calculating Pair - 1 - 5 - y1: 72.302 - y2: 144.624
#     Calculating Pair - 2 - 3 - y1: 92.302 - y2: 112.302
#     Calculating Pair - 2 - 4 - y1: 92.302 - y2: 132.302
#     Calculating Pair - 2 - 5 - y1: 92.302 - y2: 144.624
#     Calculating Pair - 3 - 4 - y1: 112.302 - y2: 132.302
#     Calculating Pair - 3 - 5 - y1: 112.302 - y2: 144.624
#     Calculating Pair - 4 - 5 - y1: 132.302 - y2: 144.624
# Calculating File - alhic2302 - 42 - l - AC
#     Calculating Pair - 0 - 1 - y1: 57.31 - y2: 77.31
#     Calculating Pair - 0 - 2 - y1: 57.31 - y2: 97.31
#     Calculating Pair - 0 - 3 - y1: 57.31 - y2: 117.31
#     Calculating Pair - 0 - 4 - y1: 57.31 - y2: 137.31
#     Calculating Pair - 0 - 5 - y1: 57.31 - y2: 151.235
#     Calculating Pair - 1 - 2 - y1: 77.31 - y2: 97.31
#     Calculating Pair - 1 - 3 - y1: 77.31 - y2: 117.31
#     Calculating Pair - 1 - 4 - y1: 77.31 - y2: 137.31
#     Calculating Pair - 1 - 5 - y1: 77.31 - y2: 151.235
#     Calculating Pair - 2 - 3 - y1: 97.31 - y2: 117.31
#     Calculating Pair - 2 - 4 - y1: 97.31 - y2: 137.31
#     Calculating Pair - 2 - 5 - y1: 97.31 - y2: 151.235
#     Calculating Pair - 3 - 4 - y1: 117.31 - y2: 137.31
#     Calculating Pair - 3 - 5 - y1: 117.31 - y2: 151.235
#     Calculating Pair - 4 - 5 - y1: 137.31 - y2: 151.235
# Calculating File - alhic2302 - 42 - t - AC
#     Calculating Pair - 0 - 1 - y1: 49.922 - y2: 69.922
#     Calculating Pair - 0 - 2 - y1: 49.922 - y2: 89.922
#     Calculating Pair - 0 - 3 - y1: 49.922 - y2: 109.922
#     Calculating Pair - 0 - 4 - y1: 49.922 - y2: 129.922
#     Calculating Pair - 0 - 5 - y1: 49.922 - y2: 146.3
#     Calculating Pair - 1 - 2 - y1: 69.922 - y2: 89.922
#     Calculating Pair - 1 - 3 - y1: 69.922 - y2: 109.922
#     Calculating Pair - 1 - 4 - y1: 69.922 - y2: 129.922
#     Calculating Pair - 1 - 5 - y1: 69.922 - y2: 146.3
#     Calculating Pair - 2 - 3 - y1: 89.922 - y2: 109.922
#     Calculating Pair - 2 - 4 - y1: 89.922 - y2: 129.922
#     Calculating Pair - 2 - 5 - y1: 89.922 - y2: 146.3
#     Calculating Pair - 3 - 4 - y1: 109.922 - y2: 129.922
#     Calculating Pair - 3 - 5 - y1: 109.922 - y2: 146.3
#     Calculating Pair - 4 - 5 - y1: 129.922 - y2: 146.3
# Calculating File - alhic2302 - 46 - l - AC
#     Calculating Pair - 0 - 1 - y1: 70.624 - y2: 90.624
#     Calculating Pair - 0 - 2 - y1: 70.624 - y2: 110.624
#     Calculating Pair - 0 - 3 - y1: 70.624 - y2: 130.624
#     Calculating Pair - 0 - 4 - y1: 70.624 - y2: 150.624
#     Calculating Pair - 0 - 5 - y1: 70.624 - y2: 156.921
#     Calculating Pair - 1 - 2 - y1: 90.624 - y2: 110.624
#     Calculating Pair - 1 - 3 - y1: 90.624 - y2: 130.624
#     Calculating Pair - 1 - 4 - y1: 90.624 - y2: 150.624
#     Calculating Pair - 1 - 5 - y1: 90.624 - y2: 156.921
#     Calculating Pair - 2 - 3 - y1: 110.624 - y2: 130.624
#     Calculating Pair - 2 - 4 - y1: 110.624 - y2: 150.624
#     Calculating Pair - 2 - 5 - y1: 110.624 - y2: 156.921
#     Calculating Pair - 3 - 4 - y1: 130.624 - y2: 150.624
#     Calculating Pair - 3 - 5 - y1: 130.624 - y2: 156.921
#     Calculating Pair - 4 - 5 - y1: 150.624 - y2: 156.921
# Calculating File - alhic2302 - 46 - t - AC
#     Calculating Pair - 0 - 1 - y1: 63.174 - y2: 83.174
#     Calculating Pair - 0 - 2 - y1: 63.174 - y2: 103.174
#     Calculating Pair - 0 - 3 - y1: 63.174 - y2: 123.174
#     Calculating Pair - 0 - 4 - y1: 63.174 - y2: 143.174
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 63.174 - y2: 159.469
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 83.174 - y2: 103.174
#     Calculating Pair - 1 - 3 - y1: 83.174 - y2: 123.174
#     Calculating Pair - 1 - 4 - y1: 83.174 - y2: 143.174
#     Calculating Pair - 1 - 5 - y1: 83.174 - y2: 159.469
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 103.174 - y2: 123.174
#     Calculating Pair - 2 - 4 - y1: 103.174 - y2: 143.174
#     Calculating Pair - 2 - 5 - y1: 103.174 - y2: 159.469
#     Calculating Pair - 3 - 4 - y1: 123.174 - y2: 143.174
#     Calculating Pair - 3 - 5 - y1: 123.174 - y2: 159.469
#     Calculating Pair - 4 - 5 - y1: 143.174 - y2: 159.469
# Calculating File - alhic2302 - 47 - l - AC
#     Calculating Pair - 0 - 1 - y1: 53.685 - y2: 73.685
#     Calculating Pair - 0 - 2 - y1: 53.685 - y2: 93.685
#     Calculating Pair - 0 - 3 - y1: 53.685 - y2: 113.685
#     Calculating Pair - 0 - 4 - y1: 53.685 - y2: 133.685
#     Calculating Pair - 0 - 5 - y1: 53.685 - y2: 144.605
#     Calculating Pair - 1 - 2 - y1: 73.685 - y2: 93.685
#     Calculating Pair - 1 - 3 - y1: 73.685 - y2: 113.685
#     Calculating Pair - 1 - 4 - y1: 73.685 - y2: 133.685
#     Calculating Pair - 1 - 5 - y1: 73.685 - y2: 144.605
#     Calculating Pair - 2 - 3 - y1: 93.685 - y2: 113.685
#     Calculating Pair - 2 - 4 - y1: 93.685 - y2: 133.685
#     Calculating Pair - 2 - 5 - y1: 93.685 - y2: 144.605
#     Calculating Pair - 3 - 4 - y1: 113.685 - y2: 133.685
#     Calculating Pair - 3 - 5 - y1: 113.685 - y2: 144.605
#     Calculating Pair - 4 - 5 - y1: 133.685 - y2: 144.605
# Calculating File - alhic2302 - 47 - t - AC
#     Calculating Pair - 0 - 1 - y1: 49.888 - y2: 69.888
#     Calculating Pair - 0 - 2 - y1: 49.888 - y2: 89.888
#     Calculating Pair - 0 - 3 - y1: 49.888 - y2: 109.888
#     Calculating Pair - 0 - 4 - y1: 49.888 - y2: 129.888
#     Calculating Pair - 0 - 5 - y1: 49.888 - y2: 140.833
#     Calculating Pair - 1 - 2 - y1: 69.888 - y2: 89.888
#     Calculating Pair - 1 - 3 - y1: 69.888 - y2: 109.888
#     Calculating Pair - 1 - 4 - y1: 69.888 - y2: 129.888
#     Calculating Pair - 1 - 5 - y1: 69.888 - y2: 140.833
#     Calculating Pair - 2 - 3 - y1: 89.888 - y2: 109.888
#     Calculating Pair - 2 - 4 - y1: 89.888 - y2: 129.888
#     Calculating Pair - 2 - 5 - y1: 89.888 - y2: 140.833
#     Calculating Pair - 3 - 4 - y1: 109.888 - y2: 129.888
#     Calculating Pair - 3 - 5 - y1: 109.888 - y2: 140.833
#     Calculating Pair - 4 - 5 - y1: 129.888 - y2: 140.833
# Calculating File - alhic2302 - 48 - l - AC
#     Calculating Pair - 0 - 1 - y1: 52.968 - y2: 72.968
#     Calculating Pair - 0 - 2 - y1: 52.968 - y2: 92.968
#     Calculating Pair - 0 - 3 - y1: 52.968 - y2: 112.968
#     Calculating Pair - 0 - 4 - y1: 52.968 - y2: 132.968
#     Calculating Pair - 0 - 5 - y1: 52.968 - y2: 143.744
#     Calculating Pair - 1 - 2 - y1: 72.968 - y2: 92.968
#     Calculating Pair - 1 - 3 - y1: 72.968 - y2: 112.968
#     Calculating Pair - 1 - 4 - y1: 72.968 - y2: 132.968
#     Calculating Pair - 1 - 5 - y1: 72.968 - y2: 143.744
#     Calculating Pair - 2 - 3 - y1: 92.968 - y2: 112.968
#     Calculating Pair - 2 - 4 - y1: 92.968 - y2: 132.968
#     Calculating Pair - 2 - 5 - y1: 92.968 - y2: 143.744
#     Calculating Pair - 3 - 4 - y1: 112.968 - y2: 132.968
#     Calculating Pair - 3 - 5 - y1: 112.968 - y2: 143.744
#     Calculating Pair - 4 - 5 - y1: 132.968 - y2: 143.744
# Calculating File - alhic2302 - 48 - t - AC
#     Calculating Pair - 0 - 1 - y1: 52.604 - y2: 72.604
#     Calculating Pair - 0 - 2 - y1: 52.604 - y2: 92.604
#     Calculating Pair - 0 - 3 - y1: 52.604 - y2: 112.604
#     Calculating Pair - 0 - 4 - y1: 52.604 - y2: 132.604
#     Calculating Pair - 0 - 5 - y1: 52.604 - y2: 142.462
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 72.604 - y2: 92.604
#     Calculating Pair - 1 - 3 - y1: 72.604 - y2: 112.604
#     Calculating Pair - 1 - 4 - y1: 72.604 - y2: 132.604
#     Calculating Pair - 1 - 5 - y1: 72.604 - y2: 142.462
#     Calculating Pair - 2 - 3 - y1: 92.604 - y2: 112.604
#     Calculating Pair - 2 - 4 - y1: 92.604 - y2: 132.604
#     Calculating Pair - 2 - 5 - y1: 92.604 - y2: 142.462
#     Calculating Pair - 3 - 4 - y1: 112.604 - y2: 132.604
#     Calculating Pair - 3 - 5 - y1: 112.604 - y2: 142.462
#     Calculating Pair - 4 - 5 - y1: 132.604 - y2: 142.462
# Calculating File - alhic2302 - 49 - l - AC
#     Calculating Pair - 0 - 1 - y1: 52.759 - y2: 72.759
#     Calculating Pair - 0 - 2 - y1: 52.759 - y2: 92.759
#     Calculating Pair - 0 - 3 - y1: 52.759 - y2: 112.759
#     Calculating Pair - 0 - 4 - y1: 52.759 - y2: 132.759
#     Calculating Pair - 0 - 5 - y1: 52.759 - y2: 146.136
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 72.759 - y2: 92.759
#     Calculating Pair - 1 - 3 - y1: 72.759 - y2: 112.759
#     Calculating Pair - 1 - 4 - y1: 72.759 - y2: 132.759
#     Calculating Pair - 1 - 5 - y1: 72.759 - y2: 146.136
#     Calculating Pair - 2 - 3 - y1: 92.759 - y2: 112.759
#     Calculating Pair - 2 - 4 - y1: 92.759 - y2: 132.759
#     Calculating Pair - 2 - 5 - y1: 92.759 - y2: 146.136
#     Calculating Pair - 3 - 4 - y1: 112.759 - y2: 132.759
#     Calculating Pair - 3 - 5 - y1: 112.759 - y2: 146.136
#     Calculating Pair - 4 - 5 - y1: 132.759 - y2: 146.136
# Calculating File - alhic2302 - 49 - t - AC
#     Calculating Pair - 0 - 1 - y1: 48.685 - y2: 68.685
#     Calculating Pair - 0 - 2 - y1: 48.685 - y2: 88.685
#     Calculating Pair - 0 - 3 - y1: 48.685 - y2: 108.685
#     Calculating Pair - 0 - 4 - y1: 48.685 - y2: 128.685
#     Calculating Pair - 0 - 5 - y1: 48.685 - y2: 144.213
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 68.685 - y2: 88.685
#     Calculating Pair - 1 - 3 - y1: 68.685 - y2: 108.685
#     Calculating Pair - 1 - 4 - y1: 68.685 - y2: 128.685
#     Calculating Pair - 1 - 5 - y1: 68.685 - y2: 144.213
#     Calculating Pair - 2 - 3 - y1: 88.685 - y2: 108.685
#     Calculating Pair - 2 - 4 - y1: 88.685 - y2: 128.685
#     Calculating Pair - 2 - 5 - y1: 88.685 - y2: 144.213
#     Calculating Pair - 3 - 4 - y1: 108.685 - y2: 128.685
#     Calculating Pair - 3 - 5 - y1: 108.685 - y2: 144.213
#     Calculating Pair - 4 - 5 - y1: 128.685 - y2: 144.213
# Calculating File - alhic2302 - 50 - l - AC
#     Calculating Pair - 0 - 1 - y1: 56.16 - y2: 76.16
#     Calculating Pair - 0 - 2 - y1: 56.16 - y2: 96.16
#     Calculating Pair - 0 - 3 - y1: 56.16 - y2: 116.16
#     Calculating Pair - 0 - 4 - y1: 56.16 - y2: 136.16
#     Calculating Pair - 0 - 5 - y1: 56.16 - y2: 146.063
#     Calculating Pair - 1 - 2 - y1: 76.16 - y2: 96.16
#     Calculating Pair - 1 - 3 - y1: 76.16 - y2: 116.16
#     Calculating Pair - 1 - 4 - y1: 76.16 - y2: 136.16
#     Calculating Pair - 1 - 5 - y1: 76.16 - y2: 146.063
#     Calculating Pair - 2 - 3 - y1: 96.16 - y2: 116.16
#     Calculating Pair - 2 - 4 - y1: 96.16 - y2: 136.16
#     Calculating Pair - 2 - 5 - y1: 96.16 - y2: 146.063
#     Calculating Pair - 3 - 4 - y1: 116.16 - y2: 136.16
#     Calculating Pair - 3 - 5 - y1: 116.16 - y2: 146.063
#     Calculating Pair - 4 - 5 - y1: 136.16 - y2: 146.063
# Calculating File - alhic2302 - 50 - t - AC
#     Calculating Pair - 0 - 1 - y1: 47.428 - y2: 67.428
#         Not enough common depths for pair
#     Calculating Pair - 0 - 2 - y1: 47.428 - y2: 87.428
#         Not enough common depths for pair
#     Calculating Pair - 0 - 3 - y1: 47.428 - y2: 107.428
#         Not enough common depths for pair
#     Calculating Pair - 0 - 4 - y1: 47.428 - y2: 127.428
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 47.428 - y2: 142.907
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 67.428 - y2: 87.428
#     Calculating Pair - 1 - 3 - y1: 67.428 - y2: 107.428
#     Calculating Pair - 1 - 4 - y1: 67.428 - y2: 127.428
#     Calculating Pair - 1 - 5 - y1: 67.428 - y2: 142.907
#     Calculating Pair - 2 - 3 - y1: 87.428 - y2: 107.428
#     Calculating Pair - 2 - 4 - y1: 87.428 - y2: 127.428
#     Calculating Pair - 2 - 5 - y1: 87.428 - y2: 142.907
#     Calculating Pair - 3 - 4 - y1: 107.428 - y2: 127.428
#     Calculating Pair - 3 - 5 - y1: 107.428 - y2: 142.907
#     Calculating Pair - 4 - 5 - y1: 127.428 - y2: 142.907
# Calculating File - alhic2302 - 51_2 - l - AC
#     Calculating Pair - 0 - 1 - y1: 58.932 - y2: 78.932
#         Not enough common depths for pair
#     Calculating Pair - 0 - 2 - y1: 58.932 - y2: 98.932
#         Not enough common depths for pair
#     Calculating Pair - 0 - 3 - y1: 58.932 - y2: 118.932
#         Not enough common depths for pair
#     Calculating Pair - 0 - 4 - y1: 58.932 - y2: 138.932
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 58.932 - y2: 149.952
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 78.932 - y2: 98.932
#         Not enough common depths for pair
#     Calculating Pair - 1 - 3 - y1: 78.932 - y2: 118.932
#         Not enough common depths for pair
#     Calculating Pair - 1 - 4 - y1: 78.932 - y2: 138.932
#         Not enough common depths for pair
#     Calculating Pair - 1 - 5 - y1: 78.932 - y2: 149.952
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 98.932 - y2: 118.932
#         Not enough common depths for pair
#     Calculating Pair - 2 - 4 - y1: 98.932 - y2: 138.932
#         Not enough common depths for pair
#     Calculating Pair - 2 - 5 - y1: 98.932 - y2: 149.952
#         Not enough common depths for pair
#     Calculating Pair - 3 - 4 - y1: 118.932 - y2: 138.932
#         Not enough common depths for pair
#     Calculating Pair - 3 - 5 - y1: 118.932 - y2: 149.952
#         Not enough common depths for pair
#     Calculating Pair - 4 - 5 - y1: 138.932 - y2: 149.952
#         Not enough common depths for pair
# Calculating File - alhic2302 - 51_2 - t - AC
#     Calculating Pair - 0 - 1 - y1: 56.071 - y2: 76.071
#     Calculating Pair - 0 - 2 - y1: 56.071 - y2: 96.071
#     Calculating Pair - 0 - 3 - y1: 56.071 - y2: 116.071
#     Calculating Pair - 0 - 4 - y1: 56.071 - y2: 136.071
#     Calculating Pair - 0 - 5 - y1: 56.071 - y2: 147.614
#     Calculating Pair - 1 - 2 - y1: 76.071 - y2: 96.071
#     Calculating Pair - 1 - 3 - y1: 76.071 - y2: 116.071
#     Calculating Pair - 1 - 4 - y1: 76.071 - y2: 136.071
#     Calculating Pair - 1 - 5 - y1: 76.071 - y2: 147.614
#     Calculating Pair - 2 - 3 - y1: 96.071 - y2: 116.071
#     Calculating Pair - 2 - 4 - y1: 96.071 - y2: 136.071
#     Calculating Pair - 2 - 5 - y1: 96.071 - y2: 147.614
#     Calculating Pair - 3 - 4 - y1: 116.071 - y2: 136.071
#     Calculating Pair - 3 - 5 - y1: 116.071 - y2: 147.614
#     Calculating Pair - 4 - 5 - y1: 136.071 - y2: 147.614
# Calculating File - alhic2302 - 52_1 - l - AC
#     Calculating Pair - 0 - 1 - y1: 62.836 - y2: 82.836
#     Calculating Pair - 0 - 2 - y1: 62.836 - y2: 102.836
#     Calculating Pair - 0 - 3 - y1: 62.836 - y2: 122.836
#     Calculating Pair - 0 - 4 - y1: 62.836 - y2: 142.836
#     Calculating Pair - 0 - 5 - y1: 62.836 - y2: 149.807
#     Calculating Pair - 1 - 2 - y1: 82.836 - y2: 102.836
#     Calculating Pair - 1 - 3 - y1: 82.836 - y2: 122.836
#     Calculating Pair - 1 - 4 - y1: 82.836 - y2: 142.836
#     Calculating Pair - 1 - 5 - y1: 82.836 - y2: 149.807
#     Calculating Pair - 2 - 3 - y1: 102.836 - y2: 122.836
#     Calculating Pair - 2 - 4 - y1: 102.836 - y2: 142.836
#     Calculating Pair - 2 - 5 - y1: 102.836 - y2: 149.807
#     Calculating Pair - 3 - 4 - y1: 122.836 - y2: 142.836
#     Calculating Pair - 3 - 5 - y1: 122.836 - y2: 149.807
#     Calculating Pair - 4 - 5 - y1: 142.836 - y2: 149.807
# Calculating File - alhic2302 - 52_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 56.493 - y2: 76.493
#     Calculating Pair - 0 - 2 - y1: 56.493 - y2: 96.493
#     Calculating Pair - 0 - 3 - y1: 56.493 - y2: 116.493
#     Calculating Pair - 0 - 4 - y1: 56.493 - y2: 136.493
#     Calculating Pair - 0 - 5 - y1: 56.493 - y2: 150.393
#     Calculating Pair - 1 - 2 - y1: 76.493 - y2: 96.493
#     Calculating Pair - 1 - 3 - y1: 76.493 - y2: 116.493
#     Calculating Pair - 1 - 4 - y1: 76.493 - y2: 136.493
#     Calculating Pair - 1 - 5 - y1: 76.493 - y2: 150.393
#     Calculating Pair - 2 - 3 - y1: 96.493 - y2: 116.493
#     Calculating Pair - 2 - 4 - y1: 96.493 - y2: 136.493
#     Calculating Pair - 2 - 5 - y1: 96.493 - y2: 150.393
#     Calculating Pair - 3 - 4 - y1: 116.493 - y2: 136.493
#     Calculating Pair - 3 - 5 - y1: 116.493 - y2: 150.393
#     Calculating Pair - 4 - 5 - y1: 136.493 - y2: 150.393

# %% [markdown]
# ## Complete ALHIC2201 Orientation Calculations

# %%
# Read in metadata and import data - ALHIC2201

# import each script as an ECM class item
data = []
cores = []
sections = []
faces = []
ACorDCs = []
max_tracks = 0
for index,row in meta.iterrows():
    
    core = row['core']
    section = row['section']
    section_num = section.split("_")
    face = row['face']
    ACorDC = row['ACorDC']
    
    if core == 'alhic2201' and ACorDC == 'AC':
            
        
        print("Reading "+core+", section "+section+'-'+face+'-'+ACorDC)
    
        data_item = ECM(core,section,face,ACorDC)
        data_item.rem_ends(10)
        data_item.smooth(window)
        data.append(data_item)
        
        cores.append(core)
        sections.append(section)
        faces.append(face)
        ACorDCs.append(ACorDC)
        
        if len(data_item.y_vec)>max_tracks:
            max_tracks = len(data_item.y_vec)
# Out:
# Reading alhic2201, section 10_1-r-AC
# Reading alhic2201, section 10_1-t-AC
# Reading alhic2201, section 11_1-r-AC
# Reading alhic2201, section 11_1-t-AC
# Reading alhic2201, section 12_1-r-AC
# Reading alhic2201, section 12_1-t-AC
# Reading alhic2201, section 13_1-r-AC
# Reading alhic2201, section 13_1-t-AC
# Reading alhic2201, section 14_1-r-AC
# Reading alhic2201, section 14_1-t-AC
# Reading alhic2201, section 15_1-r-AC
# Reading alhic2201, section 15_1-t-AC
# Reading alhic2201, section 16_1-r-AC
# Reading alhic2201, section 16_1-t-AC
# Reading alhic2201, section 18_1-r-AC
# Reading alhic2201, section 18_1-t-AC
# Reading alhic2201, section 19_1-r-AC
# Reading alhic2201, section 19_1-t-AC
# Reading alhic2201, section 1_1-r-AC
# Reading alhic2201, section 1_1-t-AC
# Reading alhic2201, section 20_1-r-AC
# Reading alhic2201, section 20_1-t-AC
# Reading alhic2201, section 21_2-r-AC
# Reading alhic2201, section 21_2-t-AC
# Reading alhic2201, section 22_1-r-AC
# Reading alhic2201, section 22_1-t-AC
# Reading alhic2201, section 23_1-r-AC
# Reading alhic2201, section 23_1-t-AC
# Reading alhic2201, section 24_1-r-AC
# Reading alhic2201, section 24_1-t-AC
# Reading alhic2201, section 25_1-r-AC
# Reading alhic2201, section 25_1-t-AC
# Reading alhic2201, section 26_1-r-AC
# Reading alhic2201, section 26_1-t-AC
# Reading alhic2201, section 2_1-r-AC
# Reading alhic2201, section 2_1-t-AC
# Reading alhic2201, section 4_2-r-AC
# Reading alhic2201, section 4_2-t-AC
# Reading alhic2201, section 5_1-r-AC
# Reading alhic2201, section 5_1-t-AC
# Reading alhic2201, section 7_1-r-AC
# Reading alhic2201, section 7_1-t-AC
# Reading alhic2201, section 8_1-t-AC
# Reading alhic2201, section 9_1-r-AC
# Reading alhic2201, section 9_1-t-AC

# %%
alhic2201 = compute_dip(data)

alhic2201.to_pickle('../../data/angles/alhic2201_angles_v2.df')
# Out:
# Calculating File - alhic2201 - 10_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 81.19 - y2: 93.19
#     Calculating Pair - 0 - 2 - y1: 81.19 - y2: 105.19
#     Calculating Pair - 0 - 3 - y1: 81.19 - y2: 112.199
#     Calculating Pair - 1 - 2 - y1: 93.19 - y2: 105.19
#     Calculating Pair - 1 - 3 - y1: 93.19 - y2: 112.199
#     Calculating Pair - 2 - 3 - y1: 105.19 - y2: 112.199
# Calculating File - alhic2201 - 10_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 34.667 - y2: 52.667
#     Calculating Pair - 0 - 2 - y1: 34.667 - y2: 70.667
#     Calculating Pair - 0 - 3 - y1: 34.667 - y2: 88.667
#     Calculating Pair - 0 - 4 - y1: 34.667 - y2: 106.667
#     Calculating Pair - 0 - 5 - y1: 34.667 - y2: 117.411
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 52.667 - y2: 70.667
#     Calculating Pair - 1 - 3 - y1: 52.667 - y2: 88.667
#     Calculating Pair - 1 - 4 - y1: 52.667 - y2: 106.667
#     Calculating Pair - 1 - 5 - y1: 52.667 - y2: 117.411
#     Calculating Pair - 2 - 3 - y1: 70.667 - y2: 88.667
#     Calculating Pair - 2 - 4 - y1: 70.667 - y2: 106.667
#     Calculating Pair - 2 - 5 - y1: 70.667 - y2: 117.411
#     Calculating Pair - 3 - 4 - y1: 88.667 - y2: 106.667
#     Calculating Pair - 3 - 5 - y1: 88.667 - y2: 117.411
#     Calculating Pair - 4 - 5 - y1: 106.667 - y2: 117.411
# Calculating File - alhic2201 - 11_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 85.386 - y2: 97.386
#     Calculating Pair - 0 - 2 - y1: 85.386 - y2: 109.386
#     Calculating Pair - 0 - 3 - y1: 85.386 - y2: 111.444
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 97.386 - y2: 109.386
#     Calculating Pair - 1 - 3 - y1: 97.386 - y2: 111.444
#     Calculating Pair - 2 - 3 - y1: 109.386 - y2: 111.444
#         Not enough separation between tracks for pair
# Calculating File - alhic2201 - 11_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 40.308 - y2: 58.308
#     Calculating Pair - 0 - 2 - y1: 40.308 - y2: 76.308
#     Calculating Pair - 0 - 3 - y1: 40.308 - y2: 94.308
#     Calculating Pair - 0 - 4 - y1: 40.308 - y2: 112.308
#     Calculating Pair - 0 - 5 - y1: 40.308 - y2: 120.623
#     Calculating Pair - 1 - 2 - y1: 58.308 - y2: 76.308
#     Calculating Pair - 1 - 3 - y1: 58.308 - y2: 94.308
#     Calculating Pair - 1 - 4 - y1: 58.308 - y2: 112.308
#     Calculating Pair - 1 - 5 - y1: 58.308 - y2: 120.623
#     Calculating Pair - 2 - 3 - y1: 76.308 - y2: 94.308
#     Calculating Pair - 2 - 4 - y1: 76.308 - y2: 112.308
#     Calculating Pair - 2 - 5 - y1: 76.308 - y2: 120.623
#     Calculating Pair - 3 - 4 - y1: 94.308 - y2: 112.308
#     Calculating Pair - 3 - 5 - y1: 94.308 - y2: 120.623
#     Calculating Pair - 4 - 5 - y1: 112.308 - y2: 120.623
# Calculating File - alhic2201 - 12_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 87.306 - y2: 99.306
#     Calculating Pair - 0 - 2 - y1: 87.306 - y2: 110.296
#     Calculating Pair - 1 - 2 - y1: 99.306 - y2: 110.296
# Calculating File - alhic2201 - 12_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 36.314 - y2: 54.314
#     Calculating Pair - 0 - 2 - y1: 36.314 - y2: 72.314
#     Calculating Pair - 0 - 3 - y1: 36.314 - y2: 90.314
#     Calculating Pair - 0 - 4 - y1: 36.314 - y2: 108.314
#     Calculating Pair - 0 - 5 - y1: 36.314 - y2: 120.296
#     Calculating Pair - 1 - 2 - y1: 54.314 - y2: 72.314
#     Calculating Pair - 1 - 3 - y1: 54.314 - y2: 90.314
#     Calculating Pair - 1 - 4 - y1: 54.314 - y2: 108.314
#     Calculating Pair - 1 - 5 - y1: 54.314 - y2: 120.296
#     Calculating Pair - 2 - 3 - y1: 72.314 - y2: 90.314
#     Calculating Pair - 2 - 4 - y1: 72.314 - y2: 108.314
#     Calculating Pair - 2 - 5 - y1: 72.314 - y2: 120.296
#     Calculating Pair - 3 - 4 - y1: 90.314 - y2: 108.314
#     Calculating Pair - 3 - 5 - y1: 90.314 - y2: 120.296
#     Calculating Pair - 4 - 5 - y1: 108.314 - y2: 120.296
# Calculating File - alhic2201 - 13_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 85.727 - y2: 95.727
#     Calculating Pair - 0 - 2 - y1: 85.727 - y2: 105.727
#     Calculating Pair - 0 - 3 - y1: 85.727 - y2: 111.673
#     Calculating Pair - 1 - 2 - y1: 95.727 - y2: 105.727
#     Calculating Pair - 1 - 3 - y1: 95.727 - y2: 111.673
#     Calculating Pair - 2 - 3 - y1: 105.727 - y2: 111.673
# Calculating File - alhic2201 - 13_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 35.857 - y2: 47.857
#     Calculating Pair - 0 - 2 - y1: 35.857 - y2: 59.857
#     Calculating Pair - 0 - 3 - y1: 35.857 - y2: 71.857
#     Calculating Pair - 0 - 4 - y1: 35.857 - y2: 83.857
#     Calculating Pair - 0 - 5 - y1: 35.857 - y2: 95.857
#     Calculating Pair - 0 - 6 - y1: 35.857 - y2: 107.857
#     Calculating Pair - 0 - 7 - y1: 35.857 - y2: 119.857
#     Calculating Pair - 0 - 8 - y1: 35.857 - y2: 120.554
#     Calculating Pair - 1 - 2 - y1: 47.857 - y2: 59.857
#     Calculating Pair - 1 - 3 - y1: 47.857 - y2: 71.857
#     Calculating Pair - 1 - 4 - y1: 47.857 - y2: 83.857
#     Calculating Pair - 1 - 5 - y1: 47.857 - y2: 95.857
#     Calculating Pair - 1 - 6 - y1: 47.857 - y2: 107.857
#     Calculating Pair - 1 - 7 - y1: 47.857 - y2: 119.857
#     Calculating Pair - 1 - 8 - y1: 47.857 - y2: 120.554
#     Calculating Pair - 2 - 3 - y1: 59.857 - y2: 71.857
#     Calculating Pair - 2 - 4 - y1: 59.857 - y2: 83.857
#     Calculating Pair - 2 - 5 - y1: 59.857 - y2: 95.857
#     Calculating Pair - 2 - 6 - y1: 59.857 - y2: 107.857
#     Calculating Pair - 2 - 7 - y1: 59.857 - y2: 119.857
#     Calculating Pair - 2 - 8 - y1: 59.857 - y2: 120.554
#     Calculating Pair - 3 - 4 - y1: 71.857 - y2: 83.857
#     Calculating Pair - 3 - 5 - y1: 71.857 - y2: 95.857
#     Calculating Pair - 3 - 6 - y1: 71.857 - y2: 107.857
#     Calculating Pair - 3 - 7 - y1: 71.857 - y2: 119.857
#     Calculating Pair - 3 - 8 - y1: 71.857 - y2: 120.554
#     Calculating Pair - 4 - 5 - y1: 83.857 - y2: 95.857
#     Calculating Pair - 4 - 6 - y1: 83.857 - y2: 107.857
#     Calculating Pair - 4 - 7 - y1: 83.857 - y2: 119.857
#     Calculating Pair - 4 - 8 - y1: 83.857 - y2: 120.554
#     Calculating Pair - 5 - 6 - y1: 95.857 - y2: 107.857
#     Calculating Pair - 5 - 7 - y1: 95.857 - y2: 119.857
#     Calculating Pair - 5 - 8 - y1: 95.857 - y2: 120.554
#     Calculating Pair - 6 - 7 - y1: 107.857 - y2: 119.857
#     Calculating Pair - 6 - 8 - y1: 107.857 - y2: 120.554
#     Calculating Pair - 7 - 8 - y1: 119.857 - y2: 120.554
#         Not enough separation between tracks for pair
# Calculating File - alhic2201 - 14_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 82.436 - y2: 92.436
#     Calculating Pair - 0 - 2 - y1: 82.436 - y2: 102.436
#     Calculating Pair - 0 - 3 - y1: 82.436 - y2: 110.921
#     Calculating Pair - 1 - 2 - y1: 92.436 - y2: 102.436
#     Calculating Pair - 1 - 3 - y1: 92.436 - y2: 110.921
#     Calculating Pair - 2 - 3 - y1: 102.436 - y2: 110.921
# Calculating File - alhic2201 - 14_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 40.222 - y2: 58.222
#     Calculating Pair - 0 - 2 - y1: 40.222 - y2: 76.222
#     Calculating Pair - 0 - 3 - y1: 40.222 - y2: 94.222
#     Calculating Pair - 0 - 4 - y1: 40.222 - y2: 112.222
#     Calculating Pair - 0 - 5 - y1: 40.222 - y2: 119.075
#     Calculating Pair - 1 - 2 - y1: 58.222 - y2: 76.222
#     Calculating Pair - 1 - 3 - y1: 58.222 - y2: 94.222
#     Calculating Pair - 1 - 4 - y1: 58.222 - y2: 112.222
#     Calculating Pair - 1 - 5 - y1: 58.222 - y2: 119.075
#     Calculating Pair - 2 - 3 - y1: 76.222 - y2: 94.222
#     Calculating Pair - 2 - 4 - y1: 76.222 - y2: 112.222
#     Calculating Pair - 2 - 5 - y1: 76.222 - y2: 119.075
#     Calculating Pair - 3 - 4 - y1: 94.222 - y2: 112.222
#     Calculating Pair - 3 - 5 - y1: 94.222 - y2: 119.075
#     Calculating Pair - 4 - 5 - y1: 112.222 - y2: 119.075
# Calculating File - alhic2201 - 15_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 87.292 - y2: 97.292
#     Calculating Pair - 0 - 2 - y1: 87.292 - y2: 107.292
#     Calculating Pair - 0 - 3 - y1: 87.292 - y2: 111.54
#     Calculating Pair - 1 - 2 - y1: 97.292 - y2: 107.292
#     Calculating Pair - 1 - 3 - y1: 97.292 - y2: 111.54
#     Calculating Pair - 2 - 3 - y1: 107.292 - y2: 111.54
#         Not enough separation between tracks for pair
# Calculating File - alhic2201 - 15_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 33.796 - y2: 51.796
#     Calculating Pair - 0 - 2 - y1: 33.796 - y2: 69.796
#     Calculating Pair - 0 - 3 - y1: 33.796 - y2: 87.796
#     Calculating Pair - 0 - 4 - y1: 33.796 - y2: 105.796
#     Calculating Pair - 0 - 5 - y1: 33.796 - y2: 118.364
#     Calculating Pair - 1 - 2 - y1: 51.796 - y2: 69.796
#     Calculating Pair - 1 - 3 - y1: 51.796 - y2: 87.796
#     Calculating Pair - 1 - 4 - y1: 51.796 - y2: 105.796
#     Calculating Pair - 1 - 5 - y1: 51.796 - y2: 118.364
#     Calculating Pair - 2 - 3 - y1: 69.796 - y2: 87.796
#     Calculating Pair - 2 - 4 - y1: 69.796 - y2: 105.796
#     Calculating Pair - 2 - 5 - y1: 69.796 - y2: 118.364
#     Calculating Pair - 3 - 4 - y1: 87.796 - y2: 105.796
#     Calculating Pair - 3 - 5 - y1: 87.796 - y2: 118.364
#     Calculating Pair - 4 - 5 - y1: 105.796 - y2: 118.364
# Calculating File - alhic2201 - 16_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 54.177 - y2: 64.177
#     Calculating Pair - 0 - 2 - y1: 54.177 - y2: 74.177
#     Calculating Pair - 0 - 3 - y1: 54.177 - y2: 82.872
#     Calculating Pair - 1 - 2 - y1: 64.177 - y2: 74.177
#     Calculating Pair - 1 - 3 - y1: 64.177 - y2: 82.872
#     Calculating Pair - 2 - 3 - y1: 74.177 - y2: 82.872
# Calculating File - alhic2201 - 16_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 34.827 - y2: 52.827
#     Calculating Pair - 0 - 2 - y1: 34.827 - y2: 70.827
#     Calculating Pair - 0 - 3 - y1: 34.827 - y2: 88.827
#     Calculating Pair - 0 - 4 - y1: 34.827 - y2: 106.827
#     Calculating Pair - 0 - 5 - y1: 34.827 - y2: 116.124
#     Calculating Pair - 1 - 2 - y1: 52.827 - y2: 70.827
#     Calculating Pair - 1 - 3 - y1: 52.827 - y2: 88.827
#     Calculating Pair - 1 - 4 - y1: 52.827 - y2: 106.827
#     Calculating Pair - 1 - 5 - y1: 52.827 - y2: 116.124
#     Calculating Pair - 2 - 3 - y1: 70.827 - y2: 88.827
#     Calculating Pair - 2 - 4 - y1: 70.827 - y2: 106.827
#     Calculating Pair - 2 - 5 - y1: 70.827 - y2: 116.124
#     Calculating Pair - 3 - 4 - y1: 88.827 - y2: 106.827
#     Calculating Pair - 3 - 5 - y1: 88.827 - y2: 116.124
#     Calculating Pair - 4 - 5 - y1: 106.827 - y2: 116.124
# Calculating File - alhic2201 - 18_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 56.472 - y2: 66.472
#     Calculating Pair - 0 - 2 - y1: 56.472 - y2: 76.472
#     Calculating Pair - 0 - 3 - y1: 56.472 - y2: 83.342
#     Calculating Pair - 1 - 2 - y1: 66.472 - y2: 76.472
#     Calculating Pair - 1 - 3 - y1: 66.472 - y2: 83.342
#     Calculating Pair - 2 - 3 - y1: 76.472 - y2: 83.342
# Calculating File - alhic2201 - 18_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 37.309 - y2: 55.309
#     Calculating Pair - 0 - 2 - y1: 37.309 - y2: 73.309
#     Calculating Pair - 0 - 3 - y1: 37.309 - y2: 91.309
#     Calculating Pair - 0 - 4 - y1: 37.309 - y2: 109.309
#     Calculating Pair - 0 - 5 - y1: 37.309 - y2: 120.234
#     Calculating Pair - 1 - 2 - y1: 55.309 - y2: 73.309
#     Calculating Pair - 1 - 3 - y1: 55.309 - y2: 91.309
#     Calculating Pair - 1 - 4 - y1: 55.309 - y2: 109.309
#     Calculating Pair - 1 - 5 - y1: 55.309 - y2: 120.234
#     Calculating Pair - 2 - 3 - y1: 73.309 - y2: 91.309
#     Calculating Pair - 2 - 4 - y1: 73.309 - y2: 109.309
#     Calculating Pair - 2 - 5 - y1: 73.309 - y2: 120.234
#     Calculating Pair - 3 - 4 - y1: 91.309 - y2: 109.309
#     Calculating Pair - 3 - 5 - y1: 91.309 - y2: 120.234
#     Calculating Pair - 4 - 5 - y1: 109.309 - y2: 120.234
# Calculating File - alhic2201 - 19_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 50.5 - y2: 60.5
#     Calculating Pair - 0 - 2 - y1: 50.5 - y2: 70.5
#     Calculating Pair - 0 - 3 - y1: 50.5 - y2: 80.5
#     Calculating Pair - 0 - 4 - y1: 50.5 - y2: 83.5
#     Calculating Pair - 1 - 2 - y1: 60.5 - y2: 70.5
#     Calculating Pair - 1 - 3 - y1: 60.5 - y2: 80.5
#     Calculating Pair - 1 - 4 - y1: 60.5 - y2: 83.5
#     Calculating Pair - 2 - 3 - y1: 70.5 - y2: 80.5
#     Calculating Pair - 2 - 4 - y1: 70.5 - y2: 83.5
#     Calculating Pair - 3 - 4 - y1: 80.5 - y2: 83.5
#         Not enough separation between tracks for pair
# Calculating File - alhic2201 - 19_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 39.431 - y2: 57.431
#         Not enough common depths for pair
#     Calculating Pair - 0 - 2 - y1: 39.431 - y2: 75.431
#         Not enough common depths for pair
#     Calculating Pair - 0 - 3 - y1: 39.431 - y2: 93.431
#         Not enough common depths for pair
#     Calculating Pair - 0 - 4 - y1: 39.431 - y2: 111.431
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 39.431 - y2: 118.83
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 57.431 - y2: 75.431
#     Calculating Pair - 1 - 3 - y1: 57.431 - y2: 93.431
#     Calculating Pair - 1 - 4 - y1: 57.431 - y2: 111.431
#     Calculating Pair - 1 - 5 - y1: 57.431 - y2: 118.83
#     Calculating Pair - 2 - 3 - y1: 75.431 - y2: 93.431
#     Calculating Pair - 2 - 4 - y1: 75.431 - y2: 111.431
#     Calculating Pair - 2 - 5 - y1: 75.431 - y2: 118.83
#     Calculating Pair - 3 - 4 - y1: 93.431 - y2: 111.431
#     Calculating Pair - 3 - 5 - y1: 93.431 - y2: 118.83
#     Calculating Pair - 4 - 5 - y1: 111.431 - y2: 118.83
# Calculating File - alhic2201 - 1_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 35.596 - y2: 45.596
#     Calculating Pair - 0 - 2 - y1: 35.596 - y2: 55.596
#     Calculating Pair - 0 - 3 - y1: 35.596 - y2: 65.596
#     Calculating Pair - 0 - 4 - y1: 35.596 - y2: 70.593
#     Calculating Pair - 1 - 2 - y1: 45.596 - y2: 55.596
#     Calculating Pair - 1 - 3 - y1: 45.596 - y2: 65.596
#     Calculating Pair - 1 - 4 - y1: 45.596 - y2: 70.593
#     Calculating Pair - 2 - 3 - y1: 55.596 - y2: 65.596
#     Calculating Pair - 2 - 4 - y1: 55.596 - y2: 70.593
#     Calculating Pair - 3 - 4 - y1: 65.596 - y2: 70.593
#         Not enough separation between tracks for pair
# Calculating File - alhic2201 - 1_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 23.728 - y2: 33.728
#     Calculating Pair - 0 - 2 - y1: 23.728 - y2: 43.728
#     Calculating Pair - 0 - 3 - y1: 23.728 - y2: 53.728
#     Calculating Pair - 0 - 4 - y1: 23.728 - y2: 63.728
#     Calculating Pair - 0 - 5 - y1: 23.728 - y2: 73.728
#     Calculating Pair - 0 - 6 - y1: 23.728 - y2: 83.728
#     Calculating Pair - 0 - 7 - y1: 23.728 - y2: 93.728
#     Calculating Pair - 0 - 8 - y1: 23.728 - y2: 103.728
#     Calculating Pair - 1 - 2 - y1: 33.728 - y2: 43.728
#     Calculating Pair - 1 - 3 - y1: 33.728 - y2: 53.728
#     Calculating Pair - 1 - 4 - y1: 33.728 - y2: 63.728
#     Calculating Pair - 1 - 5 - y1: 33.728 - y2: 73.728
#     Calculating Pair - 1 - 6 - y1: 33.728 - y2: 83.728
#     Calculating Pair - 1 - 7 - y1: 33.728 - y2: 93.728
#     Calculating Pair - 1 - 8 - y1: 33.728 - y2: 103.728
#     Calculating Pair - 2 - 3 - y1: 43.728 - y2: 53.728
#     Calculating Pair - 2 - 4 - y1: 43.728 - y2: 63.728
#     Calculating Pair - 2 - 5 - y1: 43.728 - y2: 73.728
#     Calculating Pair - 2 - 6 - y1: 43.728 - y2: 83.728
#     Calculating Pair - 2 - 7 - y1: 43.728 - y2: 93.728
#     Calculating Pair - 2 - 8 - y1: 43.728 - y2: 103.728
#     Calculating Pair - 3 - 4 - y1: 53.728 - y2: 63.728
#     Calculating Pair - 3 - 5 - y1: 53.728 - y2: 73.728
#     Calculating Pair - 3 - 6 - y1: 53.728 - y2: 83.728
#     Calculating Pair - 3 - 7 - y1: 53.728 - y2: 93.728
#     Calculating Pair - 3 - 8 - y1: 53.728 - y2: 103.728
#     Calculating Pair - 4 - 5 - y1: 63.728 - y2: 73.728
#     Calculating Pair - 4 - 6 - y1: 63.728 - y2: 83.728
#     Calculating Pair - 4 - 7 - y1: 63.728 - y2: 93.728
#     Calculating Pair - 4 - 8 - y1: 63.728 - y2: 103.728
#     Calculating Pair - 5 - 6 - y1: 73.728 - y2: 83.728
#     Calculating Pair - 5 - 7 - y1: 73.728 - y2: 93.728
#     Calculating Pair - 5 - 8 - y1: 73.728 - y2: 103.728
#     Calculating Pair - 6 - 7 - y1: 83.728 - y2: 93.728
#     Calculating Pair - 6 - 8 - y1: 83.728 - y2: 103.728
#     Calculating Pair - 7 - 8 - y1: 93.728 - y2: 103.728
# Calculating File - alhic2201 - 20_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 55.854 - y2: 65.854
#     Calculating Pair - 0 - 2 - y1: 55.854 - y2: 75.854
#     Calculating Pair - 0 - 3 - y1: 55.854 - y2: 83.374
#     Calculating Pair - 1 - 2 - y1: 65.854 - y2: 75.854
#     Calculating Pair - 1 - 3 - y1: 65.854 - y2: 83.374
#     Calculating Pair - 2 - 3 - y1: 75.854 - y2: 83.374
# Calculating File - alhic2201 - 20_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 34.228 - y2: 52.228
#     Calculating Pair - 0 - 2 - y1: 34.228 - y2: 70.228
#     Calculating Pair - 0 - 3 - y1: 34.228 - y2: 88.228
#     Calculating Pair - 0 - 4 - y1: 34.228 - y2: 106.228
#     Calculating Pair - 0 - 5 - y1: 34.228 - y2: 119.862
#     Calculating Pair - 1 - 2 - y1: 52.228 - y2: 70.228
#     Calculating Pair - 1 - 3 - y1: 52.228 - y2: 88.228
#     Calculating Pair - 1 - 4 - y1: 52.228 - y2: 106.228
#         Not enough common depths for pair
#     Calculating Pair - 1 - 5 - y1: 52.228 - y2: 119.862
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 70.228 - y2: 88.228
#     Calculating Pair - 2 - 4 - y1: 70.228 - y2: 106.228
#     Calculating Pair - 2 - 5 - y1: 70.228 - y2: 119.862
#         Not enough common depths for pair
#     Calculating Pair - 3 - 4 - y1: 88.228 - y2: 106.228
#     Calculating Pair - 3 - 5 - y1: 88.228 - y2: 119.862
#     Calculating Pair - 4 - 5 - y1: 106.228 - y2: 119.862
# Calculating File - alhic2201 - 21_2 - r - AC
#     Calculating Pair - 0 - 1 - y1: 88.147 - y2: 98.147
#     Calculating Pair - 0 - 2 - y1: 88.147 - y2: 108.147
#     Calculating Pair - 0 - 3 - y1: 88.147 - y2: 117.695
#     Calculating Pair - 1 - 2 - y1: 98.147 - y2: 108.147
#     Calculating Pair - 1 - 3 - y1: 98.147 - y2: 117.695
#     Calculating Pair - 2 - 3 - y1: 108.147 - y2: 117.695
# Calculating File - alhic2201 - 21_2 - t - AC
#     Calculating Pair - 0 - 1 - y1: 42.105 - y2: 60.105
#     Calculating Pair - 0 - 2 - y1: 42.105 - y2: 78.105
#     Calculating Pair - 0 - 3 - y1: 42.105 - y2: 96.105
#     Calculating Pair - 0 - 4 - y1: 42.105 - y2: 114.105
#     Calculating Pair - 0 - 5 - y1: 42.105 - y2: 114.336
#     Calculating Pair - 1 - 2 - y1: 60.105 - y2: 78.105
#     Calculating Pair - 1 - 3 - y1: 60.105 - y2: 96.105
#     Calculating Pair - 1 - 4 - y1: 60.105 - y2: 114.105
#     Calculating Pair - 1 - 5 - y1: 60.105 - y2: 114.336
#     Calculating Pair - 2 - 3 - y1: 78.105 - y2: 96.105
#     Calculating Pair - 2 - 4 - y1: 78.105 - y2: 114.105
#     Calculating Pair - 2 - 5 - y1: 78.105 - y2: 114.336
#     Calculating Pair - 3 - 4 - y1: 96.105 - y2: 114.105
#     Calculating Pair - 3 - 5 - y1: 96.105 - y2: 114.336
#     Calculating Pair - 4 - 5 - y1: 114.105 - y2: 114.336
#         Not enough separation between tracks for pair
# Calculating File - alhic2201 - 22_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 87.969 - y2: 97.969
#     Calculating Pair - 0 - 2 - y1: 87.969 - y2: 107.969
#     Calculating Pair - 0 - 3 - y1: 87.969 - y2: 117.969
#     Calculating Pair - 0 - 4 - y1: 87.969 - y2: 118.56
#     Calculating Pair - 1 - 2 - y1: 97.969 - y2: 107.969
#     Calculating Pair - 1 - 3 - y1: 97.969 - y2: 117.969
#     Calculating Pair - 1 - 4 - y1: 97.969 - y2: 118.56
#     Calculating Pair - 2 - 3 - y1: 107.969 - y2: 117.969
#     Calculating Pair - 2 - 4 - y1: 107.969 - y2: 118.56
#     Calculating Pair - 3 - 4 - y1: 117.969 - y2: 118.56
#         Not enough separation between tracks for pair
# Calculating File - alhic2201 - 22_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 42.72 - y2: 60.72
#     Calculating Pair - 0 - 2 - y1: 42.72 - y2: 78.72
#     Calculating Pair - 0 - 3 - y1: 42.72 - y2: 96.72
#     Calculating Pair - 0 - 4 - y1: 42.72 - y2: 114.72
#     Calculating Pair - 0 - 5 - y1: 42.72 - y2: 122.846
#     Calculating Pair - 1 - 2 - y1: 60.72 - y2: 78.72
#     Calculating Pair - 1 - 3 - y1: 60.72 - y2: 96.72
#     Calculating Pair - 1 - 4 - y1: 60.72 - y2: 114.72
#     Calculating Pair - 1 - 5 - y1: 60.72 - y2: 122.846
#     Calculating Pair - 2 - 3 - y1: 78.72 - y2: 96.72
#     Calculating Pair - 2 - 4 - y1: 78.72 - y2: 114.72
#     Calculating Pair - 2 - 5 - y1: 78.72 - y2: 122.846
#     Calculating Pair - 3 - 4 - y1: 96.72 - y2: 114.72
#     Calculating Pair - 3 - 5 - y1: 96.72 - y2: 122.846
#     Calculating Pair - 4 - 5 - y1: 114.72 - y2: 122.846
# Calculating File - alhic2201 - 23_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 58.178 - y2: 68.178
#     Calculating Pair - 0 - 2 - y1: 58.178 - y2: 78.178
#     Calculating Pair - 0 - 3 - y1: 58.178 - y2: 86.24
#     Calculating Pair - 1 - 2 - y1: 68.178 - y2: 78.178
#     Calculating Pair - 1 - 3 - y1: 68.178 - y2: 86.24
#     Calculating Pair - 2 - 3 - y1: 78.178 - y2: 86.24
# Calculating File - alhic2201 - 23_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 33.629 - y2: 51.629
#     Calculating Pair - 0 - 2 - y1: 33.629 - y2: 69.629
#     Calculating Pair - 0 - 3 - y1: 33.629 - y2: 87.629
#     Calculating Pair - 0 - 4 - y1: 33.629 - y2: 105.629
#     Calculating Pair - 0 - 5 - y1: 33.629 - y2: 116.582
#     Calculating Pair - 1 - 2 - y1: 51.629 - y2: 69.629
#     Calculating Pair - 1 - 3 - y1: 51.629 - y2: 87.629
#     Calculating Pair - 1 - 4 - y1: 51.629 - y2: 105.629
#     Calculating Pair - 1 - 5 - y1: 51.629 - y2: 116.582
#     Calculating Pair - 2 - 3 - y1: 69.629 - y2: 87.629
#     Calculating Pair - 2 - 4 - y1: 69.629 - y2: 105.629
#     Calculating Pair - 2 - 5 - y1: 69.629 - y2: 116.582
#     Calculating Pair - 3 - 4 - y1: 87.629 - y2: 105.629
#     Calculating Pair - 3 - 5 - y1: 87.629 - y2: 116.582
#     Calculating Pair - 4 - 5 - y1: 105.629 - y2: 116.582
# Calculating File - alhic2201 - 24_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 91.573 - y2: 101.573
#     Calculating Pair - 0 - 2 - y1: 91.573 - y2: 111.573
#     Calculating Pair - 0 - 3 - y1: 91.573 - y2: 116.704
#     Calculating Pair - 1 - 2 - y1: 101.573 - y2: 111.573
#     Calculating Pair - 1 - 3 - y1: 101.573 - y2: 116.704
#     Calculating Pair - 2 - 3 - y1: 111.573 - y2: 116.704
# Calculating File - alhic2201 - 24_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 39.964 - y2: 57.964
#     Calculating Pair - 0 - 2 - y1: 39.964 - y2: 75.964
#     Calculating Pair - 0 - 3 - y1: 39.964 - y2: 93.964
#     Calculating Pair - 0 - 4 - y1: 39.964 - y2: 111.964
#     Calculating Pair - 0 - 5 - y1: 39.964 - y2: 119.968
#     Calculating Pair - 1 - 2 - y1: 57.964 - y2: 75.964
#     Calculating Pair - 1 - 3 - y1: 57.964 - y2: 93.964
#     Calculating Pair - 1 - 4 - y1: 57.964 - y2: 111.964
#     Calculating Pair - 1 - 5 - y1: 57.964 - y2: 119.968
#     Calculating Pair - 2 - 3 - y1: 75.964 - y2: 93.964
#     Calculating Pair - 2 - 4 - y1: 75.964 - y2: 111.964
#     Calculating Pair - 2 - 5 - y1: 75.964 - y2: 119.968
#     Calculating Pair - 3 - 4 - y1: 93.964 - y2: 111.964
#     Calculating Pair - 3 - 5 - y1: 93.964 - y2: 119.968
#     Calculating Pair - 4 - 5 - y1: 111.964 - y2: 119.968
# Calculating File - alhic2201 - 25_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 56.758 - y2: 66.758
#     Calculating Pair - 0 - 2 - y1: 56.758 - y2: 76.758
#     Calculating Pair - 0 - 3 - y1: 56.758 - y2: 86.094
#     Calculating Pair - 1 - 2 - y1: 66.758 - y2: 76.758
#     Calculating Pair - 1 - 3 - y1: 66.758 - y2: 86.094
#     Calculating Pair - 2 - 3 - y1: 76.758 - y2: 86.094
# Calculating File - alhic2201 - 25_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 39.298 - y2: 57.298
#     Calculating Pair - 0 - 2 - y1: 39.298 - y2: 75.298
#     Calculating Pair - 0 - 3 - y1: 39.298 - y2: 93.298
#     Calculating Pair - 0 - 4 - y1: 39.298 - y2: 111.298
#     Calculating Pair - 0 - 5 - y1: 39.298 - y2: 118.673
#     Calculating Pair - 1 - 2 - y1: 57.298 - y2: 75.298
#     Calculating Pair - 1 - 3 - y1: 57.298 - y2: 93.298
#     Calculating Pair - 1 - 4 - y1: 57.298 - y2: 111.298
#     Calculating Pair - 1 - 5 - y1: 57.298 - y2: 118.673
#     Calculating Pair - 2 - 3 - y1: 75.298 - y2: 93.298
#     Calculating Pair - 2 - 4 - y1: 75.298 - y2: 111.298
#     Calculating Pair - 2 - 5 - y1: 75.298 - y2: 118.673
#     Calculating Pair - 3 - 4 - y1: 93.298 - y2: 111.298
#     Calculating Pair - 3 - 5 - y1: 93.298 - y2: 118.673
#     Calculating Pair - 4 - 5 - y1: 111.298 - y2: 118.673
# Calculating File - alhic2201 - 26_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 60.133 - y2: 70.133
#     Calculating Pair - 0 - 2 - y1: 60.133 - y2: 80.133
#     Calculating Pair - 0 - 3 - y1: 60.133 - y2: 88.217
#     Calculating Pair - 1 - 2 - y1: 70.133 - y2: 80.133
#     Calculating Pair - 1 - 3 - y1: 70.133 - y2: 88.217
#     Calculating Pair - 2 - 3 - y1: 80.133 - y2: 88.217
# Calculating File - alhic2201 - 26_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 32.916 - y2: 50.916
#     Calculating Pair - 0 - 2 - y1: 32.916 - y2: 68.916
#     Calculating Pair - 0 - 3 - y1: 32.916 - y2: 86.916
#     Calculating Pair - 0 - 4 - y1: 32.916 - y2: 104.916
#     Calculating Pair - 0 - 5 - y1: 32.916 - y2: 120.217
#     Calculating Pair - 1 - 2 - y1: 50.916 - y2: 68.916
#     Calculating Pair - 1 - 3 - y1: 50.916 - y2: 86.916
#     Calculating Pair - 1 - 4 - y1: 50.916 - y2: 104.916
#     Calculating Pair - 1 - 5 - y1: 50.916 - y2: 120.217
#     Calculating Pair - 2 - 3 - y1: 68.916 - y2: 86.916
#     Calculating Pair - 2 - 4 - y1: 68.916 - y2: 104.916
#     Calculating Pair - 2 - 5 - y1: 68.916 - y2: 120.217
#     Calculating Pair - 3 - 4 - y1: 86.916 - y2: 104.916
#     Calculating Pair - 3 - 5 - y1: 86.916 - y2: 120.217
#     Calculating Pair - 4 - 5 - y1: 104.916 - y2: 120.217
# Calculating File - alhic2201 - 2_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 52.34 - y2: 67.34
#     Calculating Pair - 0 - 2 - y1: 52.34 - y2: 82.34
#     Calculating Pair - 0 - 3 - y1: 52.34 - y2: 82.896
#     Calculating Pair - 1 - 2 - y1: 67.34 - y2: 82.34
#     Calculating Pair - 1 - 3 - y1: 67.34 - y2: 82.896
#     Calculating Pair - 2 - 3 - y1: 82.34 - y2: 82.896
#         Not enough separation between tracks for pair
# Calculating File - alhic2201 - 2_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 20.734 - y2: 35.734
#     Calculating Pair - 0 - 2 - y1: 20.734 - y2: 50.734
#     Calculating Pair - 0 - 3 - y1: 20.734 - y2: 65.734
#     Calculating Pair - 0 - 4 - y1: 20.734 - y2: 80.734
#     Calculating Pair - 0 - 5 - y1: 20.734 - y2: 95.734
#     Calculating Pair - 0 - 6 - y1: 20.734 - y2: 105.521
#     Calculating Pair - 1 - 2 - y1: 35.734 - y2: 50.734
#     Calculating Pair - 1 - 3 - y1: 35.734 - y2: 65.734
#     Calculating Pair - 1 - 4 - y1: 35.734 - y2: 80.734
#     Calculating Pair - 1 - 5 - y1: 35.734 - y2: 95.734
#     Calculating Pair - 1 - 6 - y1: 35.734 - y2: 105.521
#     Calculating Pair - 2 - 3 - y1: 50.734 - y2: 65.734
#     Calculating Pair - 2 - 4 - y1: 50.734 - y2: 80.734
#     Calculating Pair - 2 - 5 - y1: 50.734 - y2: 95.734
#     Calculating Pair - 2 - 6 - y1: 50.734 - y2: 105.521
#     Calculating Pair - 3 - 4 - y1: 65.734 - y2: 80.734
#     Calculating Pair - 3 - 5 - y1: 65.734 - y2: 95.734
#     Calculating Pair - 3 - 6 - y1: 65.734 - y2: 105.521
#     Calculating Pair - 4 - 5 - y1: 80.734 - y2: 95.734
#     Calculating Pair - 4 - 6 - y1: 80.734 - y2: 105.521
#     Calculating Pair - 5 - 6 - y1: 95.734 - y2: 105.521
# Calculating File - alhic2201 - 4_2 - r - AC
#     Calculating Pair - 0 - 1 - y1: 56.93 - y2: 71.93
#     Calculating Pair - 0 - 2 - y1: 56.93 - y2: 85.862
#     Calculating Pair - 1 - 2 - y1: 71.93 - y2: 85.862
# Calculating File - alhic2201 - 4_2 - t - AC
#     Calculating Pair - 0 - 1 - y1: 40.45 - y2: 55.45
#     Calculating Pair - 0 - 2 - y1: 40.45 - y2: 70.45
#     Calculating Pair - 0 - 3 - y1: 40.45 - y2: 85.45
#     Calculating Pair - 0 - 4 - y1: 40.45 - y2: 100.45
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 40.45 - y2: 115.45
#         Not enough common depths for pair
#     Calculating Pair - 0 - 6 - y1: 40.45 - y2: 124.62
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 55.45 - y2: 70.45
#     Calculating Pair - 1 - 3 - y1: 55.45 - y2: 85.45
#     Calculating Pair - 1 - 4 - y1: 55.45 - y2: 100.45
#     Calculating Pair - 1 - 5 - y1: 55.45 - y2: 115.45
#         Not enough common depths for pair
#     Calculating Pair - 1 - 6 - y1: 55.45 - y2: 124.62
#         Not enough common depths for pair
#     Calculating Pair - 2 - 3 - y1: 70.45 - y2: 85.45
#     Calculating Pair - 2 - 4 - y1: 70.45 - y2: 100.45
#     Calculating Pair - 2 - 5 - y1: 70.45 - y2: 115.45
#     Calculating Pair - 2 - 6 - y1: 70.45 - y2: 124.62
#     Calculating Pair - 3 - 4 - y1: 85.45 - y2: 100.45
#     Calculating Pair - 3 - 5 - y1: 85.45 - y2: 115.45
#     Calculating Pair - 3 - 6 - y1: 85.45 - y2: 124.62
#     Calculating Pair - 4 - 5 - y1: 100.45 - y2: 115.45
#     Calculating Pair - 4 - 6 - y1: 100.45 - y2: 124.62
#     Calculating Pair - 5 - 6 - y1: 115.45 - y2: 124.62
# Calculating File - alhic2201 - 5_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 56.298 - y2: 68.298
#     Calculating Pair - 0 - 2 - y1: 56.298 - y2: 80.298
#     Calculating Pair - 0 - 3 - y1: 56.298 - y2: 87.523
#     Calculating Pair - 1 - 2 - y1: 68.298 - y2: 80.298
#     Calculating Pair - 1 - 3 - y1: 68.298 - y2: 87.523
#     Calculating Pair - 2 - 3 - y1: 80.298 - y2: 87.523
# Calculating File - alhic2201 - 5_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 41.166 - y2: 53.166
#     Calculating Pair - 0 - 2 - y1: 41.166 - y2: 65.166
#     Calculating Pair - 0 - 3 - y1: 41.166 - y2: 77.166
#     Calculating Pair - 0 - 4 - y1: 41.166 - y2: 89.166
#     Calculating Pair - 0 - 5 - y1: 41.166 - y2: 101.166
#     Calculating Pair - 0 - 6 - y1: 41.166 - y2: 113.166
#     Calculating Pair - 0 - 7 - y1: 41.166 - y2: 121.228
#     Calculating Pair - 1 - 2 - y1: 53.166 - y2: 65.166
#     Calculating Pair - 1 - 3 - y1: 53.166 - y2: 77.166
#     Calculating Pair - 1 - 4 - y1: 53.166 - y2: 89.166
#     Calculating Pair - 1 - 5 - y1: 53.166 - y2: 101.166
#     Calculating Pair - 1 - 6 - y1: 53.166 - y2: 113.166
#     Calculating Pair - 1 - 7 - y1: 53.166 - y2: 121.228
#     Calculating Pair - 2 - 3 - y1: 65.166 - y2: 77.166
#     Calculating Pair - 2 - 4 - y1: 65.166 - y2: 89.166
#     Calculating Pair - 2 - 5 - y1: 65.166 - y2: 101.166
#     Calculating Pair - 2 - 6 - y1: 65.166 - y2: 113.166
#     Calculating Pair - 2 - 7 - y1: 65.166 - y2: 121.228
#     Calculating Pair - 3 - 4 - y1: 77.166 - y2: 89.166
#     Calculating Pair - 3 - 5 - y1: 77.166 - y2: 101.166
#     Calculating Pair - 3 - 6 - y1: 77.166 - y2: 113.166
#     Calculating Pair - 3 - 7 - y1: 77.166 - y2: 121.228
#     Calculating Pair - 4 - 5 - y1: 89.166 - y2: 101.166
#     Calculating Pair - 4 - 6 - y1: 89.166 - y2: 113.166
#     Calculating Pair - 4 - 7 - y1: 89.166 - y2: 121.228
#     Calculating Pair - 5 - 6 - y1: 101.166 - y2: 113.166
#     Calculating Pair - 5 - 7 - y1: 101.166 - y2: 121.228
#     Calculating Pair - 6 - 7 - y1: 113.166 - y2: 121.228
# Calculating File - alhic2201 - 7_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 56.096 - y2: 68.096
#     Calculating Pair - 0 - 2 - y1: 56.096 - y2: 80.096
#         Not enough common depths for pair
#     Calculating Pair - 0 - 3 - y1: 56.096 - y2: 85.887
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 68.096 - y2: 80.096
#     Calculating Pair - 1 - 3 - y1: 68.096 - y2: 85.887
#     Calculating Pair - 2 - 3 - y1: 80.096 - y2: 85.887
#         Not enough common depths for pair
# Calculating File - alhic2201 - 7_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 39.389 - y2: 54.389
#     Calculating Pair - 0 - 2 - y1: 39.389 - y2: 69.389
#     Calculating Pair - 0 - 3 - y1: 39.389 - y2: 84.389
#     Calculating Pair - 0 - 4 - y1: 39.389 - y2: 99.389
#     Calculating Pair - 0 - 5 - y1: 39.389 - y2: 114.389
#     Calculating Pair - 0 - 6 - y1: 39.389 - y2: 123.843
#     Calculating Pair - 1 - 2 - y1: 54.389 - y2: 69.389
#     Calculating Pair - 1 - 3 - y1: 54.389 - y2: 84.389
#     Calculating Pair - 1 - 4 - y1: 54.389 - y2: 99.389
#     Calculating Pair - 1 - 5 - y1: 54.389 - y2: 114.389
#     Calculating Pair - 1 - 6 - y1: 54.389 - y2: 123.843
#     Calculating Pair - 2 - 3 - y1: 69.389 - y2: 84.389
#     Calculating Pair - 2 - 4 - y1: 69.389 - y2: 99.389
#     Calculating Pair - 2 - 5 - y1: 69.389 - y2: 114.389
#     Calculating Pair - 2 - 6 - y1: 69.389 - y2: 123.843
#     Calculating Pair - 3 - 4 - y1: 84.389 - y2: 99.389
#     Calculating Pair - 3 - 5 - y1: 84.389 - y2: 114.389
#     Calculating Pair - 3 - 6 - y1: 84.389 - y2: 123.843
#     Calculating Pair - 4 - 5 - y1: 99.389 - y2: 114.389
#     Calculating Pair - 4 - 6 - y1: 99.389 - y2: 123.843
#     Calculating Pair - 5 - 6 - y1: 114.389 - y2: 123.843
# Calculating File - alhic2201 - 8_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 44.162 - y2: 59.162
#     Calculating Pair - 0 - 2 - y1: 44.162 - y2: 74.162
#     Calculating Pair - 0 - 3 - y1: 44.162 - y2: 89.162
#     Calculating Pair - 0 - 4 - y1: 44.162 - y2: 104.162
#     Calculating Pair - 0 - 5 - y1: 44.162 - y2: 119.162
#     Calculating Pair - 0 - 6 - y1: 44.162 - y2: 119.84
#     Calculating Pair - 1 - 2 - y1: 59.162 - y2: 74.162
#     Calculating Pair - 1 - 3 - y1: 59.162 - y2: 89.162
#     Calculating Pair - 1 - 4 - y1: 59.162 - y2: 104.162
#     Calculating Pair - 1 - 5 - y1: 59.162 - y2: 119.162
#     Calculating Pair - 1 - 6 - y1: 59.162 - y2: 119.84
#     Calculating Pair - 2 - 3 - y1: 74.162 - y2: 89.162
#     Calculating Pair - 2 - 4 - y1: 74.162 - y2: 104.162
#     Calculating Pair - 2 - 5 - y1: 74.162 - y2: 119.162
#     Calculating Pair - 2 - 6 - y1: 74.162 - y2: 119.84
#     Calculating Pair - 3 - 4 - y1: 89.162 - y2: 104.162
#     Calculating Pair - 3 - 5 - y1: 89.162 - y2: 119.162
#     Calculating Pair - 3 - 6 - y1: 89.162 - y2: 119.84
#     Calculating Pair - 4 - 5 - y1: 104.162 - y2: 119.162
#     Calculating Pair - 4 - 6 - y1: 104.162 - y2: 119.84
#     Calculating Pair - 5 - 6 - y1: 119.162 - y2: 119.84
#         Not enough separation between tracks for pair
# Calculating File - alhic2201 - 9_1 - r - AC
#     Calculating Pair - 0 - 1 - y1: 44.069 - y2: 56.069
#     Calculating Pair - 0 - 2 - y1: 44.069 - y2: 68.069
#     Calculating Pair - 0 - 3 - y1: 44.069 - y2: 80.069
#     Calculating Pair - 0 - 4 - y1: 44.069 - y2: 90.22
#     Calculating Pair - 1 - 2 - y1: 56.069 - y2: 68.069
#     Calculating Pair - 1 - 3 - y1: 56.069 - y2: 80.069
#     Calculating Pair - 1 - 4 - y1: 56.069 - y2: 90.22
#     Calculating Pair - 2 - 3 - y1: 68.069 - y2: 80.069
#         Not enough common depths for pair
#     Calculating Pair - 2 - 4 - y1: 68.069 - y2: 90.22
#     Calculating Pair - 3 - 4 - y1: 80.069 - y2: 90.22
# Calculating File - alhic2201 - 9_1 - t - AC
#     Calculating Pair - 0 - 1 - y1: 43.286 - y2: 61.286
#         Not enough common depths for pair
#     Calculating Pair - 0 - 2 - y1: 43.286 - y2: 79.286
#         Not enough common depths for pair
#     Calculating Pair - 0 - 3 - y1: 43.286 - y2: 97.286
#         Not enough common depths for pair
#     Calculating Pair - 0 - 4 - y1: 43.286 - y2: 115.286
#         Not enough common depths for pair
#     Calculating Pair - 0 - 5 - y1: 43.286 - y2: 122.579
#         Not enough common depths for pair
#     Calculating Pair - 1 - 2 - y1: 61.286 - y2: 79.286
#     Calculating Pair - 1 - 3 - y1: 61.286 - y2: 97.286
#     Calculating Pair - 1 - 4 - y1: 61.286 - y2: 115.286
#     Calculating Pair - 1 - 5 - y1: 61.286 - y2: 122.579
#     Calculating Pair - 2 - 3 - y1: 79.286 - y2: 97.286
#     Calculating Pair - 2 - 4 - y1: 79.286 - y2: 115.286
#     Calculating Pair - 2 - 5 - y1: 79.286 - y2: 122.579
#     Calculating Pair - 3 - 4 - y1: 97.286 - y2: 115.286
#     Calculating Pair - 3 - 5 - y1: 97.286 - y2: 122.579
#     Calculating Pair - 4 - 5 - y1: 115.286 - y2: 122.579
